# %% [markdown]
# ---
#
# title: **U-NET Red** Training Script
#
# author: Tiago Ribeiro
#
# date: 04/05/2023
#
# ---

# %% [markdown]
# ### 📚 Libraries

# %%
'~~ generic use libraries ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
import base64                          # decoding of base64 data
import json                            # manipulation of JSON files
import io                              # input and output stream operations
import os                              # interface with various operating systems
import glob                            # finding file paths
import numpy as np                     # mathematical and matrix operations
import matplotlib.pyplot as plt        # generating plots
import matplotlib.gridspec as gridspec # configuring grid of plots
from datetime import datetime          # manipulating dates and time
from psutil import virtual_memory      # memory usage
'~~ image manipulation ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
from PIL import ImageDraw, Image       # image manipulation
import cv2                             # computer vision and image manipulation
'~~ machine learning ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
import tensorflow as tf                   # machine learning models
from keras import backend                 # Keras low-level configurations
from sklearn.model_selection import KFold # cross-validation
'fully convolutional network layers'
from tensorflow.keras.layers import (Conv2DTranspose, Conv2D, SeparableConv2D)
from tensorflow.keras.layers import (Activation, MaxPooling2D, Concatenate)
'cost functions'
from tensorflow.keras.losses import BinaryCrossentropy  # binary cross-entropy
'metrics'
from segmentation_models.metrics import IOUScore        # Jaccard index
from tensorflow.keras.metrics import Precision 
from tensorflow.keras.metrics import Recall 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
'optimizers'
from tensorflow.keras.optimizers import Adam         # adaptive moment estimation opt.
'other'
from tensorflow.keras import Input                   # model input
from sklearn.model_selection import train_test_split # split dataset
# Out:
# Segmentation Models: using `keras` framework.

# %%
print(tf. __version__)
# Out:
# 2.10.0

# %% [markdown]
# ### 🏿 GPU and CUDA Configurations

# %%
gpu = !nvidia-smi --query-gpu=gpu_name --format=csv,noheader
ram_gb = virtual_memory().total / 1e9
print(f'{gpu.s} with {round(ram_gb,1)} GB available RAM.')
# !nvcc --version
# Out:
# NVIDIA GeForce RTX 3090 with 34.2 GB available RAM.
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_22:08:44_Pacific_Standard_Time_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %% [markdown]
# ### ⚙️ Model Configurations

# %%
CONFIGS = dict(
    W = 256,                # width
    H = 256,                # height
    C = 1,                  # RED 🔴 channel only
    BATCH_SZ = 2,           # batch size
    REF_FILTERS = 128,      # reference number for U-NET filters
    SEED = 42,              # random seed   
    F_INIT = tf.keras.initializers.HeNormal(seed=1), # Kaiming He initialization
    CLASS_NUM = 1,        
    EPOCHS = 250,          # training epochs
    OPTIMIZER = Adam(learning_rate=0.001), 
    COST_F = BinaryCrossentropy,              
    CONV_ACTIV = Activation(tf.nn.relu),    # rectified linear unit activation function
    METRICS = [IOUScore(threshold = 0.5),
               Precision(thresholds=0.5), 
               Recall(thresholds=0.5)], 
    DTYPE = np.float32                      # data type
)

# forces channel-last order (H,W,C)
backend.set_image_data_format('channels_last')

# %% [markdown]
# ### 📁 Data source paths and directories creation
#
# **note**: to test on your own machine, please set up the paths

# %%
DIR = os.getcwd() # returns the current working directory
DATASET_DIR = 'G:\\O meu disco\\BolsaInvestigacao\\'

# JSON files directories and video file path
JSON_DIR = os.path.join(DATASET_DIR, 'datasets\\fogos\\anotacoes_json')
JSON_DIR_TEST = os.path.join(DATASET_DIR, 'datasets\\fogos\\anotacoes_json_teste')

# dataset directories
IMGS_DIR_TRAIN = os.path.join(DIR, "data\\imgs_train")
MSKS_DIR_TRAIN = os.path.join(DIR, "data\\mscs_train")
IMGS_DIR_TEST = os.path.join(DIR, "data\\imgs_test")
MSKS_DIR_TEST = os.path.join(DIR, "data\\mscs_test")

# directories to store 1 (RED) channel images
IMGS_DIR_TRAIN_RED = os.path.join(DIR, "data\\imgs_train_red")
IMGS_DIR_TEST_RED = os.path.join(DIR, "data\\imgs_test_red")

# directory to save model-generated segmentations and respective frames
FRAMES_DIR = os.path.join(DIR, "data\\frames")
SEGS_DIR = os.path.join(DIR, "data\\segs")

# directory to save models and logs
CHECKPOINT_MODELOS = os.path.join(DIR, "data\\modelos")
LOGS_MODELOS = os.path.join(DIR, "data\\logs")

output_folders = [FRAMES_DIR, SEGS_DIR, CHECKPOINT_MODELOS, LOGS_MODELOS]

# create folders
for folder in output_folders:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %% [markdown]
# ### 🗃️ Auxiliary Functions

# %% [markdown]
# #### callback_funcs

# %%
def callback_funcs(str_run, monitor_metric='val_iou_score', mode='min', reduce_factor=0.5,
                   reduce_patience=10, fold_n = 0,  additional_callbacks=[]):
    """
    Creates a list of Keras callbacks to be used during model training.

    Parameters
    ----------
    str_run : str
        Prefix for the filenames of the CSVLogger and ModelCheckpoint callbacks.
    monitor_metric : str, optional
        Name of the metric to monitor for the ReduceLROnPlateau and ModelCheckpoint callbacks. 
        Default is 'loss'.
    mode : str, optional
        One of {'min', 'max', 'auto'}. 
        Specifies whether the monitored metric should be minimized, maximized, or inferred automatically for the ModelCheckpoint callback. 
        Default is 'min'.
    reduce_factor : float, optional
        Factor by which to reduce the learning rate when there is no improvement in monitored metric after reduce_patience epochs.
        Default is 0.5.
    reduce_patience : int, optional
        Number of epochs with no improvement after which to reduce the learning rate for the ReduceLROnPlateau callback.
        Default is 20.
    additional_callbacks : list, optional
        List of additional Keras callbacks to be added to the output list.
        Default is [].

    Returns
    -------
    list
        A list of Keras callbacks to be used during model training.

    """   

    # Learning Schedule
    # Reduce learning rate when there is no improvement in monitored metric after a certain number of epochs
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor=monitor_metric,
        factor=reduce_factor,
        mode=mode,
        patience=reduce_patience,
        verbose=1,
        min_lr=1e-6)
    
    # Training Logs
    # Log training metrics to a CSV file
    csv_logger = tf.keras.callbacks.CSVLogger(
        os.path.join(LOGS_MODELOS, str_run + '.csv'),
        separator=",",
        append=True)
    
    # Model Checkpoint
    # Save the best model based on monitored metric on validation data
    checkpoint_filepath = os.path.join(CHECKPOINT_MODELOS, str_run +'.h5')
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_best_only=True,
        mode=mode,
        verbose=1,
        monitor=monitor_metric)
    
    callbacks = [csv_logger, reduce_lr, checkpoint] + additional_callbacks
    
    return callbacks

# %% [markdown]
# #### create_run_string

# %%
def create_run_string(model_name = "NN", fold=None, use_cross_val=False):
    """Create a string for each training run.

    Args:
        model_name: (str,optional): the designation of the model. Defaults to "NN".
        fold (int, optional): The fold number for cross-validation. Defaults to None.
        use_cross_val (bool, optional): Whether or not to use cross-validation. Defaults to False.

    Returns:
        str: The string for the training run.
    """
    now = datetime.now()
    dt_string = now.strftime("%d_%b_%Hh%Mmin")
    str_run = f"{model_name}_{CONFIGS['W']}x{CONFIGS['H']}_F_NUM_{CONFIGS['REF_FILTERS']}_DT_{dt_string}"
    if use_cross_val:
        str_run += f"_fold_{fold}"
    return str_run

# %% [markdown]
# #### metrics_graphs

# %%
def metrics_graphs(history, model, model_conf="not provided!", metrics=['loss'], y_log=False):
    """
    Plots training and validation metrics of a Keras model during training.
    Parameters:
    -----------
    history: tf.keras.callbacks.History
        Object returned by model.fit() containing training history.
    model: tf.keras.Model
        The trained machine learning model.
    conf_modelo: str, optional (default="")
        The configuration of the model (optional)
    metrics: list of str, optional (default=['loss'])
        The metrics to plot. Must be keys in the history object.
    y_log: bool, optional(default=False) 
        Whether to use logarithmic scale for the y-axis on the loss plot. 
        Defaults to False.
    """

    if not isinstance(history, tf.keras.callbacks.History):
        raise TypeError("The 'history' argument must be a tf.keras.callbacks. History object.")
    if not isinstance(model, tf.keras.Model):
        raise TypeError("The 'model' argument must be a tf.keras.Model object.")
    if not isinstance(model_conf, str):
        raise TypeError("The 'model_conf' argument must be a string.")
        
    plt.style.use('fast') 

    n_metrics = len(metrics)
    fig, axs = plt.subplots(1, n_metrics, figsize=(25, 8))

    if n_metrics == 1:
        axs = [axs]

    for i, metric in enumerate(metrics):
        if metric not in history.history or f"val_{metric}" not in history.history:
            raise ValueError(f"{metric} not found in the history object.")

        axs[i].plot(history.history[metric], "limegreen", marker=".", alpha=0.7)
        axs[i].plot(history.history[f"val_{metric}"], "orangered", marker=".", alpha=0.7)
        axs[i].set_title(f"{metric.title()} of {model.name}\nConfiguration: {model_conf}")
        axs[i].set_ylabel(metric.title())
        axs[i].set_xlabel('Epoch')
        axs[i].legend(['train', 'validation'], loc='best')
        axs[i].grid(linestyle='--', linewidth=0.4)

        xmax = np.argmax(history.history[f"val_{metric}"])
        ymax = max(history.history[f"val_{metric}"])
        text = f"{metric.title()} Val.: {ymax:.3f}"
        bbox_props = dict(boxstyle="round,pad=0.3", fc="w", ec="k", lw=0.5)
        arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=0.3")
        kw = dict(xycoords='data', textcoords="offset points",
                  arrowprops=arrowprops1, bbox=bbox_props, ha="right", va="center")
        axs[i].annotate(text, xy=(xmax, ymax), xytext=(-15, -30), **kw)

        if metric == 'loss' and y_log:
            axs[i].set_yscale('log')

    plt.tight_layout()

# %% [markdown]
# #### preprocess_img & preprocess_msk

# %%
def preprocess_msk(msc, transp=False):
    """
    Reads an image and converts it to grayscale (1 channel) and binarizes it 
    with a threshold of 127.5.

    Args:
        msc (str): Path to the image file.
        transp (bool): Whether to transpose the output array or not. 
            Defaults to False.

    Returns:
        numpy.array: An array of shape (Channels, Width, Height) if 
        transp is False, or an array of shape (Width, Height, Channels)
        if transp is True.
    """
    # binarize the mask
    msc = (cv2.imread(msc, cv2.IMREAD_GRAYSCALE) > 127.5) * 1
    if not transp:
        msc = msc[..., np.newaxis]
    else:
        msc = msc[..., np.newaxis].transpose(2, 0, 1)
    return msc

def preprocess_img(img, transp=False):
    """
    Reads an image and normalizes it by dividing by 255. 
    It also changes the order of the image tensor from (L, A, C) to (C, L, A).

    Args:
    img (str): The path to the image file.
    transp (bool): A flag to indicate if the image tensor should be transposed. 
                   Default is False.

    Returns:
    numpy.array: The preprocessed image as a numpy array of shape (Channels, Width, Height).
    """
    # Read image in RGB format (not BGR!)
    # img = cv2.imread(img)[..., ::-1] / 255
    img = cv2.imread(img, cv2.IMREAD_UNCHANGED)[...,::-1]/255
    img = img[..., np.newaxis]
    # RED CHANNEL ONLY
    # img = img[:,:,0]
    # expand img axis

    if transp:
        img = img.transpose(2, 0, 1)

    return img

# %% [markdown]
# #### polygons_to_mask

# %%
def polygons_to_mask(img_shape, polygons):
    """
    Converts a list of polygons into a binary mask of the given shape.

    Args:
        img_shape (tuple): The shape of the output mask.
        polygons (list): A list of polygons, each represented as a list of (x, y) coordinates.

    Returns:
        A binary mask of shape `img_shape` where the pixels inside the polygons are set to True (1) and pixels outside are set to False (0).

    source: https://github.com/Jeff-sjtu/labelKeypoint/blob/master/labelme/utils.py
    """
    mask = np.zeros(img_shape[:2], dtype=np.uint8)
    mask = Image.fromarray(mask)
    xy = list(map(tuple, polygons))
    ImageDraw.Draw(mask).polygon(xy=xy, outline=1, fill=1)
    mask = np.array(mask, dtype=bool)
    
    return mask

# %% [markdown]
# #### labelme_shapes_to_label

# %%
def labelme_shapes_to_label(img_shape, shapes):
    """
    Convert a list of shapes in Labelme format to a label array and label names.

    Parameters:
        img_shape (tuple): A tuple containing the shape of the original image (height, width, channels).
        shapes (list): A list of shape dictionaries in Labelme format, each with 'label' and 'points' keys.

    Returns:
        tuple: A tuple containing:
            - lbl (numpy.ndarray): A 2D integer array of shape (height, width), where each pixel contains
              the corresponding label value. Background pixels are labeled as 0.
            - lbl_names (list): A list of label names, where lbl_names[i] corresponds to label value i.

    Source:
        https://github.com/Jeff-sjtu/labelKeypoint/blob/master/labelme/utils.py
    """

    label_name_to_val = {'background': 0}
    lbl = np.zeros(img_shape[:2], dtype=np.int32)
    for shape in shapes:
        polygons = shape['points']
        label_name = shape['label']
        if label_name in label_name_to_val:
            label_value = label_name_to_val[label_name]
        else:
            label_value = len(label_name_to_val)
            label_name_to_val[label_name] = label_value
        mask = polygons_to_mask(img_shape[:2], polygons)
        lbl[mask] = label_value

    lbl_names = [None] * (max(label_name_to_val.values()) + 1)
    for label_name, label_value in label_name_to_val.items():
        lbl_names[label_value] = label_name
        
    return lbl, lbl_names

# %% [markdown]
# #### split_data

# %%
def split_data(imgs_array, mascs_array, train_portion = 0.9, seed = CONFIGS["SEED"], shuffle = False, verbose = True):
    """
    Splits images and masks into train, validation, and test sets.

    Parameters:
        imgs_array (list): List of images.
        mascs_array (list): List of masks.
        train_portion (float): Proportion of data to use for training (0 < train_portion < 1).
        seed (int): Seed to use for random number generator to ensure reproducibility of the same data split.
        shuffle (bool): Whether to shuffle the data before splitting.
        verbose (bool): Whether to print summary statistics of the data split.

    Returns:
        Tuple of arrays with images for train, validation, and test sets (X_train, X_val, X_test), 
        and arrays with masks for train, validation, and test sets (Y_train, Y_val, Y_test).

    Example:
        If train_portion=0.9, the data will be split into 72% train / 18% validation / 10% test.
    """

    if not 0 <= train_portion <= 1:
        raise ValueError("train_portion must be between 0 and 1")

    # assert train_portion >= 0 and train_portion <= 1, "Fracão de treino inválida"
  
    if not shuffle:
        seed = None

    X_tmp, X_test, Y_tmp, Y_test = train_test_split(imgs_array, 
                                                    mascs_array, 
                                                    train_size = train_portion, 
                                                    random_state = seed,
                                                    shuffle = shuffle )

    X_tr, X_val, Y_tr, Y_val = train_test_split(X_tmp, 
                                                Y_tmp, 
                                                train_size = 0.8, 
                                                random_state = seed,
                                                shuffle = shuffle )

    if verbose:
        print(f" Training set ({round((len(X_tr)/len(imgs_array))*100)}%): {len(X_tr)} images and {len(Y_tr)} masks")
        print(f" Validation set ({round((len(X_val)/len(imgs_array))*100)}%): {len(X_val)} images and {len(Y_val)} masks")
        print(f" Teste set ({round((len(X_test)/len(imgs_array))*100)}%): {len(X_test)} images and {len(Y_test)} masks")

    return X_tr, X_val, X_test, Y_tr, Y_val, Y_test

# %% [markdown]
# #### generate_batch

# %%
def generate_batch(data, batch_size, unitary_batch=False):
    """
    Generates batches of data with size equal to `batch_size`. The last batch is discarded
    to prevent compatibility issues with the output data format.

    Args:
        data (list of lists): Input data, where the first list contains images and the second list
                              contains masks.
        batch_size (int): The size of each batch.
        unitary_batch (bool, optional): If True, generates a single batch for sanity check. Defaults to False.

    Yields:
        tuple of numpy arrays: A generator of batches that produces X and y, where X is a numpy array of
                               'batch_size' sequences of images and y is a numpy array of 'batch_size'
                               sequences of masks.

    Raises:
        Exception: If an error occurs during image preprocessing.

    """
    # Convert list of lists to numpy array
    data = np.array(data)

    if unitary_batch:
        sample_num = 2 * batch_size
    else: 
        sample_num = len(data[0])

    while True:
        # Discard last batch
        for offset in range(0, sample_num - batch_size, batch_size):
            imgs_lote = data[0, offset: offset + batch_size]
            masc_lote = data[1, offset: offset + batch_size]

            X, y = list(), list()

            # For each batch:
            for img, msk in zip(imgs_lote, masc_lote):
                try:
                    # Preprocess images and masks
                    img = preprocess_img(img)
                    msk = preprocess_msk(msk)
                    X.append(img)
                    y.append(msk)
                except Exception as e:
                    raise Exception(f'Error {e} reading file: {img}')

            # Convert list to numpy array of type float32
            X = np.array(X).astype(np.float32)
            y = np.array(y).astype(np.float32)

            # Yield batch of data
            yield X, y

# %% [markdown]
# #### img_b64_to_array

# %%
def img_b64_to_array(img_b64):
    """
    The img_b64_to_array function takes a base64 encoded image and returns a 
    numpy array of the decoded image.

    Parameters:
    img_b64 (str): a base64 encoded image.

    Returns:
    img_arr (numpy array): a numpy array representing the decoded image.

    Source: https://github.com/Jeff-sjtu/labelKeypoint/blob/master/labelme/utils.py.
    """
    f = io.BytesIO()
    f.write(base64.b64decode(img_b64))
    img_arr = np.array(Image.open(f))
    return img_arr

# %% [markdown]
# #### json2data

# %%
def json2data(json_dir, out_dir_imgs, out_dir_msks, img_size=(256, 256)):
    """
    Convert json files created in Labelme to images and masks in *.png format.

    Args:
        json_dir (str): Path to directory containing *.json files.
        out_dir_imgs (str): Destination path for the images.
        out_dir_msks (str): Destination path for the masks.
        img_size (tuple): Size of the output images and masks.

    Raises:
        ValueError: If the dimensions of the image and mask arrays do not match.

    """
    try:
        # create output directory for images
        os.makedirs(out_dir_imgs, exist_ok=True)
        # create output directory for masks
        os.makedirs(out_dir_msks, exist_ok=True)

        # Create a list of all json files in the directory
        files = glob.glob(os.path.join(json_dir, "*.json"))
        print(f"Converting {len(files)} json files...")

        for file in files:
            # Extract data from json file
            data = json.load(open(file))
            # Convert segmentation polygons to mask
            img = img_b64_to_array(data['imageData'])
            # convert segmentation polygons to mask
            msk_l, _ = labelme_shapes_to_label(img.shape, data['shapes'])
            # Resize image and mask
            img = cv2.resize(img, dsize=(img_size[0], img_size[1]), interpolation=cv2.INTER_LINEAR)
            msk = cv2.resize(np.array(msk_l, dtype='uint8'), dsize=(img_size[0], img_size[1]))*255
            # Extract frame index number from filename: 'frame_######
            base = os.path.splitext(os.path.basename(file))[0]
            num_frame = base.split('_')[1]
            # Save image (in RGB mode!!) and mask to *.png file
            cv2.imwrite(os.path.join(out_dir_imgs, base + ".png"), cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
            cv2.imwrite(os.path.join(out_dir_msks, 'mask_' + str(num_frame) + ".png"), msk)
        print(f"Conversion completed. {len(files)} images and respective masks were created.")

    except Exception as e:
        print(f"Error converting json files: {e}")

# %% [markdown]
# ### ✨ Converting JSON images and masks to PNG

# %%
# Convert JSON files to images and segmentation masks
# training and validation data
json2data(json_dir=JSON_DIR, out_dir_imgs=IMGS_DIR_TRAIN, 
          out_dir_msks=MSKS_DIR_TRAIN, 
          img_size=(CONFIGS['H'], CONFIGS['W']))
# test data      
json2data(json_dir=JSON_DIR_TEST, 
          out_dir_imgs=IMGS_DIR_TEST, 
          out_dir_msks=MSKS_DIR_TEST, 
          img_size=(CONFIGS['H'], CONFIGS['W']))
# Out:
# Converting 227 json files...
# Conversion completed. 227 images and respective masks were created.
# Converting 23 json files...
# Conversion completed. 23 images and respective masks were created.

# %%
# extracts from image and mask file paths
imgs_paths = sorted(glob.glob(IMGS_DIR_TRAIN + '\\*.png'))
msks_paths = sorted(glob.glob(MSKS_DIR_TRAIN + '\\*.png'))
imgs_path_test = sorted(glob.glob(IMGS_DIR_TEST + '\\*.png'))
msks_path_test = sorted(glob.glob(MSKS_DIR_TEST + '\\*.png'))

# %%
print("Converting training RGB images to single channel 🔴...")
for i in range(len(imgs_paths)):
    # read in RGB mode (instead of BGR): [...,::-1]
    img = cv2.imread(imgs_paths[i])[...,::-1]
    img_red = img[:,:,0]
    cv2.imwrite(os.path.join(IMGS_DIR_TRAIN_RED, "frame_" + str(i).zfill(6) + ".png"), np.expand_dims(img_red, axis=2))
# extract and sort image file paths
imgs_path_train_red = sorted(glob.glob(IMGS_DIR_TRAIN_RED + '\*.png'))
print(f'{len(imgs_path_train_red)} training images converted.')
# Out:
# Converting training RGB images to single channel 🔴...
# 227 training images converted.

# %%
print("Converting RGB test images to single-channel 🔴...")
for i in range(len(imgs_path_test)):
    # read in RGB mode (instead of BGR)
    img = cv2.imread(imgs_path_test[i])[...,::-1]
    img_red = img[:,:,0]
    cv2.imwrite(os.path.join(IMGS_DIR_TEST_RED, "frame_" + str(i).zfill(6) + ".png"), np.expand_dims(img_red, axis=2))

#extract and sort the image file paths
imgs_path_test_red = sorted(glob.glob(IMGS_DIR_TEST_RED + '\*.png'))
print(f'{len(imgs_path_test_red)} test images converted.')
# Out:
# Converting RGB test images to single-channel 🔴...
# 23 test images converted.

# %% [markdown]
# ### 🔩 Model Definition

# %% [markdown]
# #### 📏 **U-NET RED**

# %%
def conv_block(input, filters, f_init=CONFIGS['F_INIT']):
    """
    Apply two convolutional layers with ReLU activation function.

    Args:
        input (tensor): Input tensor to the block.
        filters (int): Number of filters in the convolutional layers.

    Returns:
        tensor: Output tensor of the block with ReLU activation.
    """
    x = SeparableConv2D(filters, 
                        kernel_size = (3,3), 
                        depthwise_initializer = f_init,
                        pointwise_initializer = f_init,
                        padding="same")(input)
    x = Activation(tf.nn.relu)(x)

    x = SeparableConv2D(filters, 
                        kernel_size = (3,3), 
                        depthwise_initializer = f_init,
                        pointwise_initializer = f_init,
                        padding="same")(x)
    activation = Activation(tf.nn.relu)(x)
    
    return activation

def encoder(input, filters, f_init=CONFIGS['F_INIT']):
    """
    A convolutional block followed by max pooling.

    Args:
        input (tensor): Input tensor.
        filters (int): Number of filters in the convolutional block.
        f_init (str): String indicating the initialization method for filters.
        Default is taken from CONFIGS.

    Returns:
        tuple: Tuple containing the activation map tensor and the output tensor 
        of the max pooling layer.
    """
    # Apply convolutional block
    ativ = conv_block(input, filters, f_init=f_init)
    # Apply max pooling layer
    m_pool = MaxPooling2D(pool_size=(2, 2),
                          strides=2,
                          data_format="channels_last",
                          padding='same')(ativ)
    return ativ, m_pool

def decoder(input, ativ_skip, filters, f_init=CONFIGS['F_INIT']):
    """
    Transposed 2D convolution layer (its output is concatenated with the 
    corresponding encoder activation map), followed by 2 convolutional layers 
    with ReLU activation.

    Args:
        input: input tensor
        ativ_skip: skip connection tensor from the corresponding encoder layer
        filters: number of filters in the convolutional layers

    Returns:
        ativ: tensor containing the output of the decoder layer
    """
    x = Conv2DTranspose(filters, 
                        kernel_size = (3,3), 
                        strides=2,
                        kernel_initializer = f_init,
                        data_format = "channels_last", 
                        padding="same")(input)
    # concatenates activation map with skip connection
    x = Concatenate()([x, ativ_skip])
    ativ = conv_block(x, filters)

    return ativ

# %% [markdown]
# #### create_UNET_RED

# %%
def create_UNET_RED(img_dim=(256,256), ref_filters=128, num_classes=1, batch_sz=2):
    """
    Creates a U-Net model for image segmentation, with variable input image 
    dimensions and zero padding. This architecture has 4 max pooling layers (2x2) 
    with stride 2 in the contraction phase (encoder), which means that the input 
    image dimensions will be divided by 16 (2^4).

    Args:
        dim_img (tuple, optional): Input image dimensions. Defaults to (256,256).
        ref_filters (int, optional): Number of filters to use in the initial layer. Defaults to 128.
        num_classes (int, optional): Number of classes to classify. Defaults to 1.
        batch_sz (int, optional): Batch size. Defaults to 2.

    Returns:
        tf.keras.Model: The U-Net model.
    """
    # input layer
    input_layer = Input(img_dim + (1,), batch_size=batch_sz)
    # encoder/contraction phase
    activ1, cod1 = encoder(input_layer, ref_filters)
    activ2, cod2 = encoder(cod1, ref_filters * 2)
    activ3, cod3 = encoder(cod2, ref_filters * 4)
    activ4, cod4 = encoder(cod3, ref_filters * 8)
    # bridge
    bridge = conv_block(cod4, ref_filters * 16)
    # decoder/expansion phase
    dec1 = decoder(bridge, activ4, ref_filters * 8)
    dec2 = decoder(dec1, activ3, ref_filters * 4)
    dec3 = decoder(dec2, activ2, ref_filters * 2)
    dec4 = decoder(dec3, activ1, ref_filters)
    # output layer
    if num_classes > 1:
        activ_func = 'softmax'
    else:
        activ_func = 'sigmoid'

    output_layer = Conv2D(num_classes, kernel_size=(1, 1), activation=activ_func,
                          data_format="channels_last", padding="same")(dec4)

    # U-Net model
    unet_model = tf.keras.Model(input_layer, output_layer)
    return unet_model

# %%
model = create_UNET_RED()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(2, 256, 256, 1)]   0           []
#
#  separable_conv2d (SeparableCon  (2, 256, 256, 128)  265         ['input_1[0][0]']
#  v2D)
#
#  activation_1 (Activation)      (2, 256, 256, 128)   0           ['separable_conv2d[0][0]']
#
#  separable_conv2d_1 (SeparableC  (2, 256, 256, 128)  17664       ['activation_1[0][0]']
#  onv2D)
#
#  activation_2 (Activation)      (2, 256, 256, 128)   0           ['separable_conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (2, 128, 128, 128)   0           ['activation_2[0][0]']
#
#  separable_conv2d_2 (SeparableC  (2, 128, 128, 256)  34176       ['max_pooling2d[0][0]']
#  onv2D)
#
#  activation_3 (Activation)      (2, 128, 128, 256)   0           ['separable_conv2d_2[0][0]']
#
#  separable_conv2d_3 (SeparableC  (2, 128, 128, 256)  68096       ['activation_3[0][0]']
#  onv2D)
#
#  activation_4 (Activation)      (2, 128, 128, 256)   0           ['separable_conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (2, 64, 64, 256)    0           ['activation_4[0][0]']
#
#  separable_conv2d_4 (SeparableC  (2, 64, 64, 512)    133888      ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  activation_5 (Activation)      (2, 64, 64, 512)     0           ['separable_conv2d_4[0][0]']
#
#  separable_conv2d_5 (SeparableC  (2, 64, 64, 512)    267264      ['activation_5[0][0]']
#  onv2D)
#
#  activation_6 (Activation)      (2, 64, 64, 512)     0           ['separable_conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (2, 32, 32, 512)    0           ['activation_6[0][0]']
#
#  separable_conv2d_6 (SeparableC  (2, 32, 32, 1024)   529920      ['max_pooling2d_2[0][0]']
#  onv2D)
#
#  activation_7 (Activation)      (2, 32, 32, 1024)    0           ['separable_conv2d_6[0][0]']
#
#  separable_conv2d_7 (SeparableC  (2, 32, 32, 1024)   1058816     ['activation_7[0][0]']
#  onv2D)
#
#  activation_8 (Activation)      (2, 32, 32, 1024)    0           ['separable_conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (2, 16, 16, 1024)   0           ['activation_8[0][0]']
#
#  separable_conv2d_8 (SeparableC  (2, 16, 16, 2048)   2108416     ['max_pooling2d_3[0][0]']
#  onv2D)
#
#  activation_9 (Activation)      (2, 16, 16, 2048)    0           ['separable_conv2d_8[0][0]']
#
#  separable_conv2d_9 (SeparableC  (2, 16, 16, 2048)   4214784     ['activation_9[0][0]']
#  onv2D)
#
#  activation_10 (Activation)     (2, 16, 16, 2048)    0           ['separable_conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (2, 32, 32, 1024)   18875392    ['activation_10[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (2, 32, 32, 2048)    0           ['conv2d_transpose[0][0]',
#                                                                   'activation_8[0][0]']
#
#  separable_conv2d_10 (Separable  (2, 32, 32, 1024)   2116608     ['concatenate[0][0]']
#  Conv2D)
#
#  activation_11 (Activation)     (2, 32, 32, 1024)    0           ['separable_conv2d_10[0][0]']
#
#  separable_conv2d_11 (Separable  (2, 32, 32, 1024)   1058816     ['activation_11[0][0]']
#  Conv2D)
#
#  activation_12 (Activation)     (2, 32, 32, 1024)    0           ['separable_conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (2, 64, 64, 512)    4719104     ['activation_12[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (2, 64, 64, 1024)    0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_6[0][0]']
#
#  separable_conv2d_12 (Separable  (2, 64, 64, 512)    534016      ['concatenate_1[0][0]']
#  Conv2D)
#
#  activation_13 (Activation)     (2, 64, 64, 512)     0           ['separable_conv2d_12[0][0]']
#
#  separable_conv2d_13 (Separable  (2, 64, 64, 512)    267264      ['activation_13[0][0]']
#  Conv2D)
#
#  activation_14 (Activation)     (2, 64, 64, 512)     0           ['separable_conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (2, 128, 128, 256)  1179904     ['activation_14[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (2, 128, 128, 512)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_4[0][0]']
#
#  separable_conv2d_14 (Separable  (2, 128, 128, 256)  135936      ['concatenate_2[0][0]']
#  Conv2D)
#
#  activation_15 (Activation)     (2, 128, 128, 256)   0           ['separable_conv2d_14[0][0]']
#
#  separable_conv2d_15 (Separable  (2, 128, 128, 256)  68096       ['activation_15[0][0]']
#  Conv2D)
#
#  activation_16 (Activation)     (2, 128, 128, 256)   0           ['separable_conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (2, 256, 256, 128)  295040      ['activation_16[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (2, 256, 256, 256)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  separable_conv2d_16 (Separable  (2, 256, 256, 128)  35200       ['concatenate_3[0][0]']
#  Conv2D)
#
#  activation_17 (Activation)     (2, 256, 256, 128)   0           ['separable_conv2d_16[0][0]']
#
#  separable_conv2d_17 (Separable  (2, 256, 256, 128)  17664       ['activation_17[0][0]']
#  Conv2D)
#
#  activation_18 (Activation)     (2, 256, 256, 128)   0           ['separable_conv2d_17[0][0]']
#
#  conv2d (Conv2D)                (2, 256, 256, 1)     129         ['activation_18[0][0]']
#
# ==================================================================================================
# Total params: 37,736,458
# Trainable params: 37,736,458
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 🧪 Experiment

# %% [markdown]
# #### ✔️ Cross validation

# %%
# Create a K-fold cross-validator with 3 splits, shuffling the data and using a fixed random state
k_part = KFold(n_splits=3, shuffle=True, random_state=CONFIGS['SEED'])
# Counter for current fold
fold_n = 1 
# Lists to store metric values and training histories for each fold
vc_sc_train, vc_sc_valid, vc_sc_test, histories = list(), list(), list(),list()

# Clear any previously created models from memory
backend.clear_session()

# Create data generators for test set
generator_test = generate_batch([imgs_path_test_red, msks_path_test], 
                                batch_size=CONFIGS["BATCH_SZ"])

# Loop through each fold
for tr_indices, val_indices in k_part.split(X=np.array(imgs_path_train_red), y=np.array(msks_paths)):
    
    # Clear any previously created models from memory
    #backend.clear_session()
    
    # Create string run and callback functions
    str_run = create_run_string(model_name='unet',fold=fold_n, use_cross_val=True)
    print(str_run)
    cllbcks = callback_funcs(str_run, fold_n = fold_n, mode='max')

    # Create data generators for training and validation sets
    generator_train = generate_batch([np.array(imgs_path_train_red)[tr_indices], 
                                      np.array(msks_paths)[tr_indices]], 
                                      batch_size=CONFIGS["BATCH_SZ"])
    generator_valid = generate_batch([np.array(imgs_path_train_red)[val_indices], 
                                      np.array(msks_paths)[val_indices]], 
                                      batch_size=CONFIGS["BATCH_SZ"])
    
    # Create and compile the U-Net model
    model = None
    model = create_UNET_RED(img_dim= (CONFIGS['H'], CONFIGS['W']), 
                            ref_filters=CONFIGS['REF_FILTERS'], 
                            batch_sz=CONFIGS['BATCH_SZ'])
    
    model.compile(optimizer=CONFIGS['OPTIMIZER'], 
                  loss='binary_crossentropy', 
                  metrics=CONFIGS['METRICS'])
    
    # Train the model
    history = model.fit(generator_train,
                        validation_data=generator_valid,
                        epochs=CONFIGS['EPOCHS'],
                        batch_size=CONFIGS['BATCH_SZ'],
                        verbose=1,
                        steps_per_epoch=len(tr_indices) // CONFIGS['BATCH_SZ'],
                        validation_steps=len(val_indices) // CONFIGS['BATCH_SZ'],
                        validation_batch_size=CONFIGS['BATCH_SZ'],
                        callbacks=cllbcks)
    
    # Evaluate the model on training, validation, and test sets and print metrics
    score_train = model.evaluate(generator_train, 
                           steps=len(imgs_path_train_red) // CONFIGS['BATCH_SZ'], 
                           verbose=0)

    print(f'Training Metrics\n IoU = {score_train[1]*100:.2f} %\
          \n Precision = {score_train[2]*100:.2f} %\
          \n Recall = {score_train[3]*100:.2f} %')
    
    score_valid = model.evaluate(generator_valid, 
                           steps=len(val_indices) // CONFIGS['BATCH_SZ'], 
                           verbose=0)
    print(f'Validation Metrics\n IoU = {score_valid[1]*100:.2f} %\
          \n Recall = {score_valid[2]*100:.2f} %\
          \n Precision = {score_valid[3]*100:.2f} %')
            
        
    # concatenate the test scores and histories for each fold´
    vc_sc_train.append(score_train)
    vc_sc_valid.append(score_valid)
    histories.append(history)
    fold_n += 1

    # redifines learning rate
    lr_atual = model.optimizer.lr.read_value()
    if lr_atual != 0.001:
        print(f'After fold training, learning rate reposition from {lr_atual} to 0,001')
        model.optimizer.lr.assign(0.001)
# Out:
# unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1
# Epoch 1/250
# 75/75 [==============================] - ETA: 0s - loss: 0.6423 - iou_score: 8.1040e-04 - precision: 0.1277 - recall: 6.7996e-04
# Epoch 1: val_iou_score improved from -inf to 0.00000, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 16s 90ms/step - loss: 0.6423 - iou_score: 8.1040e-04 - precision: 0.1277 - recall: 6.7996e-04 - val_loss: 0.6293 - val_iou_score: 2.9375e-10 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/250
# 75/75 [==============================] - ETA: 0s - loss: 0.6036 - iou_score: 3.0161e-10 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_iou_score did not improve from 0.00000
# 75/75 [==============================] - 6s 74ms/step - loss: 0.6036 - iou_score: 3.0161e-10 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6441 - val_iou_score: 2.9316e-10 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5944 - iou_score: 3.0161e-10 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_iou_score did not improve from 0.00000
# 75/75 [==============================] - 5s 73ms/step - loss: 0.5944 - iou_score: 3.0161e-10 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6268 - val_iou_score: 2.9242e-10 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5520 - iou_score: 0.0311 - precision: 0.5839 - recall: 0.0694
# Epoch 4: val_iou_score improved from 0.00000 to 0.18700, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 86ms/step - loss: 0.5520 - iou_score: 0.0311 - precision: 0.5839 - recall: 0.0694 - val_loss: 0.5821 - val_iou_score: 0.1870 - val_precision: 0.4406 - val_recall: 0.2807 - lr: 0.0010
# Epoch 5/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5362 - iou_score: 0.0050 - precision: 0.5551 - recall: 0.0073
# Epoch 5: val_iou_score did not improve from 0.18700
# 75/75 [==============================] - 5s 73ms/step - loss: 0.5362 - iou_score: 0.0050 - precision: 0.5551 - recall: 0.0073 - val_loss: 0.5985 - val_iou_score: 0.1857 - val_precision: 0.4541 - val_recall: 0.2668 - lr: 0.0010
# Epoch 6/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5324 - iou_score: 0.0246 - precision: 0.7023 - recall: 0.0405
# Epoch 6: val_iou_score did not improve from 0.18700
# 75/75 [==============================] - 6s 76ms/step - loss: 0.5324 - iou_score: 0.0246 - precision: 0.7023 - recall: 0.0405 - val_loss: 0.5632 - val_iou_score: 0.1779 - val_precision: 0.4665 - val_recall: 0.2443 - lr: 0.0010
# Epoch 7/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5145 - iou_score: 0.1783 - precision: 0.6037 - recall: 0.3247
# Epoch 7: val_iou_score improved from 0.18700 to 0.26382, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 0.5145 - iou_score: 0.1783 - precision: 0.6037 - recall: 0.3247 - val_loss: 0.5990 - val_iou_score: 0.2638 - val_precision: 0.4857 - val_recall: 0.3970 - lr: 0.0010
# Epoch 8/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5084 - iou_score: 0.1816 - precision: 0.6363 - recall: 0.3180
# Epoch 8: val_iou_score improved from 0.26382 to 0.41368, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 0.5084 - iou_score: 0.1816 - precision: 0.6363 - recall: 0.3180 - val_loss: 0.6111 - val_iou_score: 0.4137 - val_precision: 0.4974 - val_recall: 0.7281 - lr: 0.0010
# Epoch 9/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5138 - iou_score: 0.0885 - precision: 0.5856 - recall: 0.1781
# Epoch 9: val_iou_score improved from 0.41368 to 0.42308, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 86ms/step - loss: 0.5138 - iou_score: 0.0885 - precision: 0.5856 - recall: 0.1781 - val_loss: 0.5649 - val_iou_score: 0.4231 - val_precision: 0.4908 - val_recall: 0.7637 - lr: 0.0010
# Epoch 10/250
# 75/75 [==============================] - ETA: 0s - loss: 0.5041 - iou_score: 0.1642 - precision: 0.6225 - recall: 0.2920
# Epoch 10: val_iou_score improved from 0.42308 to 0.50046, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 85ms/step - loss: 0.5041 - iou_score: 0.1642 - precision: 0.6225 - recall: 0.2920 - val_loss: 0.8403 - val_iou_score: 0.5005 - val_precision: 0.5460 - val_recall: 0.8635 - lr: 0.0010
# Epoch 11/250
# 75/75 [==============================] - ETA: 0s - loss: 0.4310 - iou_score: 0.3189 - precision: 0.7845 - recall: 0.4870
# Epoch 11: val_iou_score improved from 0.50046 to 0.58863, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 85ms/step - loss: 0.4310 - iou_score: 0.3189 - precision: 0.7845 - recall: 0.4870 - val_loss: 0.4729 - val_iou_score: 0.5886 - val_precision: 0.6834 - val_recall: 0.8230 - lr: 0.0010
# Epoch 12/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3364 - iou_score: 0.5053 - precision: 0.8028 - recall: 0.6716
# Epoch 12: val_iou_score improved from 0.58863 to 0.61462, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 0.3364 - iou_score: 0.5053 - precision: 0.8028 - recall: 0.6716 - val_loss: 0.6525 - val_iou_score: 0.6146 - val_precision: 0.6630 - val_recall: 0.8873 - lr: 0.0010
# Epoch 13/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3984 - iou_score: 0.4811 - precision: 0.7345 - recall: 0.6804
# Epoch 13: val_iou_score did not improve from 0.61462
# 75/75 [==============================] - 6s 76ms/step - loss: 0.3984 - iou_score: 0.4811 - precision: 0.7345 - recall: 0.6804 - val_loss: 0.4294 - val_iou_score: 0.5839 - val_precision: 0.6167 - val_recall: 0.9110 - lr: 0.0010
# Epoch 14/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3655 - iou_score: 0.5054 - precision: 0.7469 - recall: 0.6974
# Epoch 14: val_iou_score improved from 0.61462 to 0.61912, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 0.3655 - iou_score: 0.5054 - precision: 0.7469 - recall: 0.6974 - val_loss: 0.5308 - val_iou_score: 0.6191 - val_precision: 0.6526 - val_recall: 0.9199 - lr: 0.0010
# Epoch 15/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3326 - iou_score: 0.5689 - precision: 0.7593 - recall: 0.7376
# Epoch 15: val_iou_score did not improve from 0.61912
# 75/75 [==============================] - 6s 74ms/step - loss: 0.3326 - iou_score: 0.5689 - precision: 0.7593 - recall: 0.7376 - val_loss: 0.4927 - val_iou_score: 0.5766 - val_precision: 0.5867 - val_recall: 0.9590 - lr: 0.0010
# Epoch 16/250
# 75/75 [==============================] - ETA: 0s - loss: 0.4148 - iou_score: 0.4730 - precision: 0.7177 - recall: 0.6574
# Epoch 16: val_iou_score did not improve from 0.61912
# 75/75 [==============================] - 6s 74ms/step - loss: 0.4148 - iou_score: 0.4730 - precision: 0.7177 - recall: 0.6574 - val_loss: 0.5046 - val_iou_score: 0.5649 - val_precision: 0.5814 - val_recall: 0.9370 - lr: 0.0010
# Epoch 17/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3793 - iou_score: 0.5621 - precision: 0.7145 - recall: 0.7484
# Epoch 17: val_iou_score did not improve from 0.61912
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3793 - iou_score: 0.5621 - precision: 0.7145 - recall: 0.7484 - val_loss: 0.7570 - val_iou_score: 0.5734 - val_precision: 0.5759 - val_recall: 0.9696 - lr: 0.0010
# Epoch 18/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3378 - iou_score: 0.6233 - precision: 0.7867 - recall: 0.7765
# Epoch 18: val_iou_score did not improve from 0.61912
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3378 - iou_score: 0.6233 - precision: 0.7867 - recall: 0.7765 - val_loss: 0.4297 - val_iou_score: 0.6056 - val_precision: 0.6194 - val_recall: 0.9486 - lr: 0.0010
# Epoch 19/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2823 - iou_score: 0.6477 - precision: 0.8249 - recall: 0.7654
# Epoch 19: val_iou_score improved from 0.61912 to 0.61989, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 0.2823 - iou_score: 0.6477 - precision: 0.8249 - recall: 0.7654 - val_loss: 0.4944 - val_iou_score: 0.6199 - val_precision: 0.6424 - val_recall: 0.9373 - lr: 0.0010
# Epoch 20/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2708 - iou_score: 0.6391 - precision: 0.8417 - recall: 0.7571
# Epoch 20: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2708 - iou_score: 0.6391 - precision: 0.8417 - recall: 0.7571 - val_loss: 0.5419 - val_iou_score: 0.5828 - val_precision: 0.5895 - val_recall: 0.9572 - lr: 0.0010
# Epoch 21/250
# 75/75 [==============================] - ETA: 0s - loss: 0.3063 - iou_score: 0.6012 - precision: 0.8236 - recall: 0.7212
# Epoch 21: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3063 - iou_score: 0.6012 - precision: 0.8236 - recall: 0.7212 - val_loss: 0.4846 - val_iou_score: 0.5979 - val_precision: 0.6075 - val_recall: 0.9648 - lr: 0.0010
# Epoch 22/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2670 - iou_score: 0.6136 - precision: 0.8390 - recall: 0.7269
# Epoch 22: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2670 - iou_score: 0.6136 - precision: 0.8390 - recall: 0.7269 - val_loss: 0.5343 - val_iou_score: 0.5803 - val_precision: 0.5816 - val_recall: 0.9759 - lr: 0.0010
# Epoch 23/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2876 - iou_score: 0.6217 - precision: 0.8211 - recall: 0.7370
# Epoch 23: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 75ms/step - loss: 0.2876 - iou_score: 0.6217 - precision: 0.8211 - recall: 0.7370 - val_loss: 0.5003 - val_iou_score: 0.6056 - val_precision: 0.6112 - val_recall: 0.9718 - lr: 0.0010
# Epoch 24/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2634 - iou_score: 0.6247 - precision: 0.8371 - recall: 0.7317
# Epoch 24: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2634 - iou_score: 0.6247 - precision: 0.8371 - recall: 0.7317 - val_loss: 0.5345 - val_iou_score: 0.5861 - val_precision: 0.5849 - val_recall: 0.9832 - lr: 0.0010
# Epoch 25/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2623 - iou_score: 0.6531 - precision: 0.8323 - recall: 0.7628
# Epoch 25: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2623 - iou_score: 0.6531 - precision: 0.8323 - recall: 0.7628 - val_loss: 0.5029 - val_iou_score: 0.5813 - val_precision: 0.5768 - val_recall: 0.9902 - lr: 0.0010
# Epoch 26/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2583 - iou_score: 0.6751 - precision: 0.8244 - recall: 0.7911
# Epoch 26: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2583 - iou_score: 0.6751 - precision: 0.8244 - recall: 0.7911 - val_loss: 0.4755 - val_iou_score: 0.5965 - val_precision: 0.5938 - val_recall: 0.9914 - lr: 0.0010
# Epoch 27/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2401 - iou_score: 0.6963 - precision: 0.8264 - recall: 0.8225
# Epoch 27: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2401 - iou_score: 0.6963 - precision: 0.8264 - recall: 0.8225 - val_loss: 0.4722 - val_iou_score: 0.6060 - val_precision: 0.6063 - val_recall: 0.9886 - lr: 0.0010
# Epoch 28/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2290 - iou_score: 0.6886 - precision: 0.8365 - recall: 0.8135
# Epoch 28: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2290 - iou_score: 0.6886 - precision: 0.8365 - recall: 0.8135 - val_loss: 0.4997 - val_iou_score: 0.5874 - val_precision: 0.5835 - val_recall: 0.9930 - lr: 0.0010
# Epoch 29/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2368 - iou_score: 0.7163 - precision: 0.8288 - recall: 0.8385
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 29: val_iou_score did not improve from 0.61989
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2368 - iou_score: 0.7163 - precision: 0.8288 - recall: 0.8385 - val_loss: 0.5298 - val_iou_score: 0.6005 - val_precision: 0.5973 - val_recall: 0.9921 - lr: 0.0010
# Epoch 30/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2711 - iou_score: 0.6935 - precision: 0.7897 - recall: 0.8383
# Epoch 30: val_iou_score improved from 0.61989 to 0.67247, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.2711 - iou_score: 0.6935 - precision: 0.7897 - recall: 0.8383 - val_loss: 0.3186 - val_iou_score: 0.6725 - val_precision: 0.6878 - val_recall: 0.9706 - lr: 5.0000e-04
# Epoch 31/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2572 - iou_score: 0.6924 - precision: 0.7959 - recall: 0.8408
# Epoch 31: val_iou_score improved from 0.67247 to 0.68075, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.2572 - iou_score: 0.6924 - precision: 0.7959 - recall: 0.8408 - val_loss: 0.3062 - val_iou_score: 0.6808 - val_precision: 0.7001 - val_recall: 0.9659 - lr: 5.0000e-04
# Epoch 32/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2554 - iou_score: 0.6934 - precision: 0.7964 - recall: 0.8421
# Epoch 32: val_iou_score improved from 0.68075 to 0.69315, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 80ms/step - loss: 0.2554 - iou_score: 0.6934 - precision: 0.7964 - recall: 0.8421 - val_loss: 0.2878 - val_iou_score: 0.6931 - val_precision: 0.7194 - val_recall: 0.9576 - lr: 5.0000e-04
# Epoch 33/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2463 - iou_score: 0.6951 - precision: 0.8074 - recall: 0.8359
# Epoch 33: val_iou_score improved from 0.69315 to 0.69619, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.2463 - iou_score: 0.6951 - precision: 0.8074 - recall: 0.8359 - val_loss: 0.2826 - val_iou_score: 0.6962 - val_precision: 0.7229 - val_recall: 0.9569 - lr: 5.0000e-04
# Epoch 34/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2397 - iou_score: 0.7018 - precision: 0.8110 - recall: 0.8428
# Epoch 34: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2397 - iou_score: 0.7018 - precision: 0.8110 - recall: 0.8428 - val_loss: 0.2837 - val_iou_score: 0.6942 - val_precision: 0.7174 - val_recall: 0.9637 - lr: 5.0000e-04
# Epoch 35/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2346 - iou_score: 0.7053 - precision: 0.8147 - recall: 0.8445
# Epoch 35: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2346 - iou_score: 0.7053 - precision: 0.8147 - recall: 0.8445 - val_loss: 0.2778 - val_iou_score: 0.6960 - val_precision: 0.7210 - val_recall: 0.9622 - lr: 5.0000e-04
# Epoch 36/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2239 - iou_score: 0.7154 - precision: 0.8230 - recall: 0.8508
# Epoch 36: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2239 - iou_score: 0.7154 - precision: 0.8230 - recall: 0.8508 - val_loss: 0.2839 - val_iou_score: 0.6940 - val_precision: 0.7147 - val_recall: 0.9675 - lr: 5.0000e-04
# Epoch 37/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2211 - iou_score: 0.7174 - precision: 0.8265 - recall: 0.8506
# Epoch 37: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2211 - iou_score: 0.7174 - precision: 0.8265 - recall: 0.8506 - val_loss: 0.2807 - val_iou_score: 0.6961 - val_precision: 0.7185 - val_recall: 0.9671 - lr: 5.0000e-04
# Epoch 38/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2159 - iou_score: 0.7236 - precision: 0.8285 - recall: 0.8558
# Epoch 38: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 5s 73ms/step - loss: 0.2159 - iou_score: 0.7236 - precision: 0.8285 - recall: 0.8558 - val_loss: 0.2893 - val_iou_score: 0.6809 - val_precision: 0.6992 - val_recall: 0.9739 - lr: 5.0000e-04
# Epoch 39/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2158 - iou_score: 0.7234 - precision: 0.8288 - recall: 0.8559
# Epoch 39: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2158 - iou_score: 0.7234 - precision: 0.8288 - recall: 0.8559 - val_loss: 0.2825 - val_iou_score: 0.6814 - val_precision: 0.7021 - val_recall: 0.9727 - lr: 5.0000e-04
# Epoch 40/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2043 - iou_score: 0.7377 - precision: 0.8376 - recall: 0.8668
# Epoch 40: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 6s 74ms/step - loss: 0.2043 - iou_score: 0.7377 - precision: 0.8376 - recall: 0.8668 - val_loss: 0.2776 - val_iou_score: 0.6861 - val_precision: 0.7073 - val_recall: 0.9740 - lr: 5.0000e-04
# Epoch 41/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1971 - iou_score: 0.7440 - precision: 0.8424 - recall: 0.8707
# Epoch 41: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 5s 73ms/step - loss: 0.1971 - iou_score: 0.7440 - precision: 0.8424 - recall: 0.8707 - val_loss: 0.2691 - val_iou_score: 0.6907 - val_precision: 0.7122 - val_recall: 0.9755 - lr: 5.0000e-04
# Epoch 42/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1903 - iou_score: 0.7509 - precision: 0.8474 - recall: 0.8761
# Epoch 42: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1903 - iou_score: 0.7509 - precision: 0.8474 - recall: 0.8761 - val_loss: 0.2862 - val_iou_score: 0.6837 - val_precision: 0.7014 - val_recall: 0.9789 - lr: 5.0000e-04
# Epoch 43/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1892 - iou_score: 0.7507 - precision: 0.8457 - recall: 0.8780
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 43: val_iou_score did not improve from 0.69619
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1892 - iou_score: 0.7507 - precision: 0.8457 - recall: 0.8780 - val_loss: 0.2898 - val_iou_score: 0.6829 - val_precision: 0.7004 - val_recall: 0.9773 - lr: 5.0000e-04
# Epoch 44/250
# 75/75 [==============================] - ETA: 0s - loss: 0.2047 - iou_score: 0.7280 - precision: 0.8330 - recall: 0.8594
# Epoch 44: val_iou_score improved from 0.69619 to 0.72254, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 0.2047 - iou_score: 0.7280 - precision: 0.8330 - recall: 0.8594 - val_loss: 0.2335 - val_iou_score: 0.7225 - val_precision: 0.7534 - val_recall: 0.9658 - lr: 2.5000e-04
# Epoch 45/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1871 - iou_score: 0.7473 - precision: 0.8518 - recall: 0.8716
# Epoch 45: val_iou_score improved from 0.72254 to 0.73423, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1871 - iou_score: 0.7473 - precision: 0.8518 - recall: 0.8716 - val_loss: 0.2167 - val_iou_score: 0.7342 - val_precision: 0.7710 - val_recall: 0.9609 - lr: 2.5000e-04
# Epoch 46/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1793 - iou_score: 0.7556 - precision: 0.8640 - recall: 0.8701
# Epoch 46: val_iou_score improved from 0.73423 to 0.74569, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1793 - iou_score: 0.7556 - precision: 0.8640 - recall: 0.8701 - val_loss: 0.2043 - val_iou_score: 0.7457 - val_precision: 0.7867 - val_recall: 0.9556 - lr: 2.5000e-04
# Epoch 47/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1738 - iou_score: 0.7609 - precision: 0.8668 - recall: 0.8750
# Epoch 47: val_iou_score improved from 0.74569 to 0.75098, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1738 - iou_score: 0.7609 - precision: 0.8668 - recall: 0.8750 - val_loss: 0.2009 - val_iou_score: 0.7510 - val_precision: 0.7913 - val_recall: 0.9575 - lr: 2.5000e-04
# Epoch 48/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1647 - iou_score: 0.7730 - precision: 0.8778 - recall: 0.8787
# Epoch 48: val_iou_score improved from 0.75098 to 0.75301, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 80ms/step - loss: 0.1647 - iou_score: 0.7730 - precision: 0.8778 - recall: 0.8787 - val_loss: 0.2022 - val_iou_score: 0.7530 - val_precision: 0.7927 - val_recall: 0.9585 - lr: 2.5000e-04
# Epoch 49/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1621 - iou_score: 0.7758 - precision: 0.8798 - recall: 0.8804
# Epoch 49: val_iou_score improved from 0.75301 to 0.75859, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1621 - iou_score: 0.7758 - precision: 0.8798 - recall: 0.8804 - val_loss: 0.1987 - val_iou_score: 0.7586 - val_precision: 0.7974 - val_recall: 0.9592 - lr: 2.5000e-04
# Epoch 50/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1590 - iou_score: 0.7779 - precision: 0.8847 - recall: 0.8780
# Epoch 50: val_iou_score improved from 0.75859 to 0.76496, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.1590 - iou_score: 0.7779 - precision: 0.8847 - recall: 0.8780 - val_loss: 0.1921 - val_iou_score: 0.7650 - val_precision: 0.8060 - val_recall: 0.9575 - lr: 2.5000e-04
# Epoch 51/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1512 - iou_score: 0.7889 - precision: 0.8898 - recall: 0.8873
# Epoch 51: val_iou_score improved from 0.76496 to 0.77543, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1512 - iou_score: 0.7889 - precision: 0.8898 - recall: 0.8873 - val_loss: 0.1890 - val_iou_score: 0.7754 - val_precision: 0.8206 - val_recall: 0.9522 - lr: 2.5000e-04
# Epoch 52/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1404 - iou_score: 0.8036 - precision: 0.9015 - recall: 0.8952
# Epoch 52: val_iou_score improved from 0.77543 to 0.78091, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1404 - iou_score: 0.8036 - precision: 0.9015 - recall: 0.8952 - val_loss: 0.1942 - val_iou_score: 0.7809 - val_precision: 0.8275 - val_recall: 0.9502 - lr: 2.5000e-04
# Epoch 53/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1353 - iou_score: 0.8104 - precision: 0.9059 - recall: 0.8981
# Epoch 53: val_iou_score improved from 0.78091 to 0.78439, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1353 - iou_score: 0.8104 - precision: 0.9059 - recall: 0.8981 - val_loss: 0.1871 - val_iou_score: 0.7844 - val_precision: 0.8329 - val_recall: 0.9477 - lr: 2.5000e-04
# Epoch 54/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1274 - iou_score: 0.8181 - precision: 0.9143 - recall: 0.8994
# Epoch 54: val_iou_score improved from 0.78439 to 0.78479, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1274 - iou_score: 0.8181 - precision: 0.9143 - recall: 0.8994 - val_loss: 0.1980 - val_iou_score: 0.7848 - val_precision: 0.8307 - val_recall: 0.9513 - lr: 2.5000e-04
# Epoch 55/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1256 - iou_score: 0.8181 - precision: 0.9133 - recall: 0.9016
# Epoch 55: val_iou_score improved from 0.78479 to 0.78718, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.1256 - iou_score: 0.8181 - precision: 0.9133 - recall: 0.9016 - val_loss: 0.2038 - val_iou_score: 0.7872 - val_precision: 0.8305 - val_recall: 0.9548 - lr: 2.5000e-04
# Epoch 56/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1216 - iou_score: 0.8228 - precision: 0.9185 - recall: 0.9008
# Epoch 56: val_iou_score did not improve from 0.78718
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1216 - iou_score: 0.8228 - precision: 0.9185 - recall: 0.9008 - val_loss: 0.2066 - val_iou_score: 0.7869 - val_precision: 0.8294 - val_recall: 0.9575 - lr: 2.5000e-04
# Epoch 57/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1169 - iou_score: 0.8250 - precision: 0.9226 - recall: 0.8993
# Epoch 57: val_iou_score did not improve from 0.78718
# 75/75 [==============================] - 6s 75ms/step - loss: 0.1169 - iou_score: 0.8250 - precision: 0.9226 - recall: 0.8993 - val_loss: 0.2282 - val_iou_score: 0.7840 - val_precision: 0.8283 - val_recall: 0.9545 - lr: 2.5000e-04
# Epoch 58/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1199 - iou_score: 0.8291 - precision: 0.9205 - recall: 0.9051
# Epoch 58: val_iou_score did not improve from 0.78718
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1199 - iou_score: 0.8291 - precision: 0.9205 - recall: 0.9051 - val_loss: 0.2222 - val_iou_score: 0.7796 - val_precision: 0.8196 - val_recall: 0.9613 - lr: 2.5000e-04
# Epoch 59/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1163 - iou_score: 0.8281 - precision: 0.9221 - recall: 0.9028
# Epoch 59: val_iou_score improved from 0.78718 to 0.79501, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.1163 - iou_score: 0.8281 - precision: 0.9221 - recall: 0.9028 - val_loss: 0.1827 - val_iou_score: 0.7950 - val_precision: 0.8440 - val_recall: 0.9434 - lr: 2.5000e-04
# Epoch 60/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1170 - iou_score: 0.8262 - precision: 0.9208 - recall: 0.9003
# Epoch 60: val_iou_score improved from 0.79501 to 0.80057, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1170 - iou_score: 0.8262 - precision: 0.9208 - recall: 0.9003 - val_loss: 0.1730 - val_iou_score: 0.8006 - val_precision: 0.8536 - val_recall: 0.9395 - lr: 2.5000e-04
# Epoch 61/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1110 - iou_score: 0.8339 - precision: 0.9225 - recall: 0.9073
# Epoch 61: val_iou_score improved from 0.80057 to 0.80614, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1110 - iou_score: 0.8339 - precision: 0.9225 - recall: 0.9073 - val_loss: 0.1632 - val_iou_score: 0.8061 - val_precision: 0.8659 - val_recall: 0.9300 - lr: 2.5000e-04
# Epoch 62/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1086 - iou_score: 0.8393 - precision: 0.9227 - recall: 0.9119
# Epoch 62: val_iou_score did not improve from 0.80614
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1086 - iou_score: 0.8393 - precision: 0.9227 - recall: 0.9119 - val_loss: 0.1632 - val_iou_score: 0.8031 - val_precision: 0.8610 - val_recall: 0.9331 - lr: 2.5000e-04
# Epoch 63/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1051 - iou_score: 0.8442 - precision: 0.9253 - recall: 0.9166
# Epoch 63: val_iou_score did not improve from 0.80614
# 75/75 [==============================] - 6s 74ms/step - loss: 0.1051 - iou_score: 0.8442 - precision: 0.9253 - recall: 0.9166 - val_loss: 0.1589 - val_iou_score: 0.8044 - val_precision: 0.8491 - val_recall: 0.9529 - lr: 2.5000e-04
# Epoch 64/250
# 75/75 [==============================] - ETA: 0s - loss: 0.1043 - iou_score: 0.8432 - precision: 0.9248 - recall: 0.9182
# Epoch 64: val_iou_score improved from 0.80614 to 0.80890, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.1043 - iou_score: 0.8432 - precision: 0.9248 - recall: 0.9182 - val_loss: 0.1584 - val_iou_score: 0.8089 - val_precision: 0.8498 - val_recall: 0.9557 - lr: 2.5000e-04
# Epoch 65/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0983 - iou_score: 0.8551 - precision: 0.9290 - recall: 0.9261
# Epoch 65: val_iou_score did not improve from 0.80890
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0983 - iou_score: 0.8551 - precision: 0.9290 - recall: 0.9261 - val_loss: 0.1772 - val_iou_score: 0.7988 - val_precision: 0.8396 - val_recall: 0.9559 - lr: 2.5000e-04
# Epoch 66/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0954 - iou_score: 0.8588 - precision: 0.9320 - recall: 0.9268
# Epoch 66: val_iou_score did not improve from 0.80890
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0954 - iou_score: 0.8588 - precision: 0.9320 - recall: 0.9268 - val_loss: 0.1863 - val_iou_score: 0.7983 - val_precision: 0.8381 - val_recall: 0.9571 - lr: 2.5000e-04
# Epoch 67/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0942 - iou_score: 0.8604 - precision: 0.9323 - recall: 0.9276
# Epoch 67: val_iou_score did not improve from 0.80890
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0942 - iou_score: 0.8604 - precision: 0.9323 - recall: 0.9276 - val_loss: 0.1777 - val_iou_score: 0.8039 - val_precision: 0.8455 - val_recall: 0.9563 - lr: 2.5000e-04
# Epoch 68/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0956 - iou_score: 0.8575 - precision: 0.9344 - recall: 0.9207
# Epoch 68: val_iou_score did not improve from 0.80890
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0956 - iou_score: 0.8575 - precision: 0.9344 - recall: 0.9207 - val_loss: 0.1806 - val_iou_score: 0.7995 - val_precision: 0.8432 - val_recall: 0.9532 - lr: 2.5000e-04
# Epoch 69/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0990 - iou_score: 0.8516 - precision: 0.9301 - recall: 0.9194
# Epoch 69: val_iou_score did not improve from 0.80890
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0990 - iou_score: 0.8516 - precision: 0.9301 - recall: 0.9194 - val_loss: 0.1685 - val_iou_score: 0.8057 - val_precision: 0.8539 - val_recall: 0.9489 - lr: 2.5000e-04
# Epoch 70/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0990 - iou_score: 0.8521 - precision: 0.9299 - recall: 0.9183
# Epoch 70: val_iou_score improved from 0.80890 to 0.82008, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0990 - iou_score: 0.8521 - precision: 0.9299 - recall: 0.9183 - val_loss: 0.1502 - val_iou_score: 0.8201 - val_precision: 0.8792 - val_recall: 0.9368 - lr: 2.5000e-04
# Epoch 71/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0972 - iou_score: 0.8531 - precision: 0.9325 - recall: 0.9171
# Epoch 71: val_iou_score did not improve from 0.82008
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0972 - iou_score: 0.8531 - precision: 0.9325 - recall: 0.9171 - val_loss: 0.1538 - val_iou_score: 0.8160 - val_precision: 0.8646 - val_recall: 0.9484 - lr: 2.5000e-04
# Epoch 72/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0955 - iou_score: 0.8578 - precision: 0.9354 - recall: 0.9215
# Epoch 72: val_iou_score improved from 0.82008 to 0.82111, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0955 - iou_score: 0.8578 - precision: 0.9354 - recall: 0.9215 - val_loss: 0.1599 - val_iou_score: 0.8211 - val_precision: 0.8748 - val_recall: 0.9442 - lr: 2.5000e-04
# Epoch 73/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0893 - iou_score: 0.8644 - precision: 0.9370 - recall: 0.9264
# Epoch 73: val_iou_score improved from 0.82111 to 0.83180, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0893 - iou_score: 0.8644 - precision: 0.9370 - recall: 0.9264 - val_loss: 0.1383 - val_iou_score: 0.8318 - val_precision: 0.8900 - val_recall: 0.9390 - lr: 2.5000e-04
# Epoch 74/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0885 - iou_score: 0.8640 - precision: 0.9351 - recall: 0.9279
# Epoch 74: val_iou_score improved from 0.83180 to 0.83475, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0885 - iou_score: 0.8640 - precision: 0.9351 - recall: 0.9279 - val_loss: 0.1338 - val_iou_score: 0.8347 - val_precision: 0.8990 - val_recall: 0.9320 - lr: 2.5000e-04
# Epoch 75/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0850 - iou_score: 0.8688 - precision: 0.9375 - recall: 0.9301
# Epoch 75: val_iou_score improved from 0.83475 to 0.83580, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 86ms/step - loss: 0.0850 - iou_score: 0.8688 - precision: 0.9375 - recall: 0.9301 - val_loss: 0.1262 - val_iou_score: 0.8358 - val_precision: 0.9074 - val_recall: 0.9244 - lr: 2.5000e-04
# Epoch 76/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0808 - iou_score: 0.8746 - precision: 0.9393 - recall: 0.9351
# Epoch 76: val_iou_score improved from 0.83580 to 0.84168, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 0.0808 - iou_score: 0.8746 - precision: 0.9393 - recall: 0.9351 - val_loss: 0.1241 - val_iou_score: 0.8417 - val_precision: 0.9086 - val_recall: 0.9285 - lr: 2.5000e-04
# Epoch 77/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0774 - iou_score: 0.8812 - precision: 0.9426 - recall: 0.9389
# Epoch 77: val_iou_score improved from 0.84168 to 0.84345, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.0774 - iou_score: 0.8812 - precision: 0.9426 - recall: 0.9389 - val_loss: 0.1224 - val_iou_score: 0.8435 - val_precision: 0.9048 - val_recall: 0.9344 - lr: 2.5000e-04
# Epoch 78/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0753 - iou_score: 0.8831 - precision: 0.9431 - recall: 0.9406
# Epoch 78: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0753 - iou_score: 0.8831 - precision: 0.9431 - recall: 0.9406 - val_loss: 0.1235 - val_iou_score: 0.8395 - val_precision: 0.9083 - val_recall: 0.9270 - lr: 2.5000e-04
# Epoch 79/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0733 - iou_score: 0.8849 - precision: 0.9435 - recall: 0.9425
# Epoch 79: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0733 - iou_score: 0.8849 - precision: 0.9435 - recall: 0.9425 - val_loss: 0.1282 - val_iou_score: 0.8372 - val_precision: 0.9119 - val_recall: 0.9201 - lr: 2.5000e-04
# Epoch 80/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0707 - iou_score: 0.8900 - precision: 0.9453 - recall: 0.9465
# Epoch 80: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 76ms/step - loss: 0.0707 - iou_score: 0.8900 - precision: 0.9453 - recall: 0.9465 - val_loss: 0.1355 - val_iou_score: 0.8338 - val_precision: 0.9066 - val_recall: 0.9219 - lr: 2.5000e-04
# Epoch 81/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0688 - iou_score: 0.8923 - precision: 0.9464 - recall: 0.9485
# Epoch 81: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0688 - iou_score: 0.8923 - precision: 0.9464 - recall: 0.9485 - val_loss: 0.1407 - val_iou_score: 0.8321 - val_precision: 0.9006 - val_recall: 0.9273 - lr: 2.5000e-04
# Epoch 82/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0671 - iou_score: 0.8937 - precision: 0.9485 - recall: 0.9465
# Epoch 82: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 77ms/step - loss: 0.0671 - iou_score: 0.8937 - precision: 0.9485 - recall: 0.9465 - val_loss: 0.1599 - val_iou_score: 0.8331 - val_precision: 0.9095 - val_recall: 0.9188 - lr: 2.5000e-04
# Epoch 83/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0711 - iou_score: 0.8918 - precision: 0.9471 - recall: 0.9461
# Epoch 83: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0711 - iou_score: 0.8918 - precision: 0.9471 - recall: 0.9461 - val_loss: 0.1607 - val_iou_score: 0.8256 - val_precision: 0.9163 - val_recall: 0.9021 - lr: 2.5000e-04
# Epoch 84/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0674 - iou_score: 0.8927 - precision: 0.9474 - recall: 0.9475
# Epoch 84: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0674 - iou_score: 0.8927 - precision: 0.9474 - recall: 0.9475 - val_loss: 0.1448 - val_iou_score: 0.8358 - val_precision: 0.9294 - val_recall: 0.8987 - lr: 2.5000e-04
# Epoch 85/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0646 - iou_score: 0.8987 - precision: 0.9498 - recall: 0.9507
# Epoch 85: val_iou_score did not improve from 0.84345
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0646 - iou_score: 0.8987 - precision: 0.9498 - recall: 0.9507 - val_loss: 0.1389 - val_iou_score: 0.8399 - val_precision: 0.9288 - val_recall: 0.9049 - lr: 2.5000e-04
# Epoch 86/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0613 - iou_score: 0.9005 - precision: 0.9516 - recall: 0.9513
# Epoch 86: val_iou_score improved from 0.84345 to 0.85109, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.0613 - iou_score: 0.9005 - precision: 0.9516 - recall: 0.9513 - val_loss: 0.1430 - val_iou_score: 0.8511 - val_precision: 0.9243 - val_recall: 0.9215 - lr: 2.5000e-04
# Epoch 87/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0631 - iou_score: 0.9017 - precision: 0.9516 - recall: 0.9525
# Epoch 87: val_iou_score improved from 0.85109 to 0.85257, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.0631 - iou_score: 0.9017 - precision: 0.9516 - recall: 0.9525 - val_loss: 0.1300 - val_iou_score: 0.8526 - val_precision: 0.9149 - val_recall: 0.9334 - lr: 2.5000e-04
# Epoch 88/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0598 - iou_score: 0.9050 - precision: 0.9538 - recall: 0.9550
# Epoch 88: val_iou_score improved from 0.85257 to 0.85311, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0598 - iou_score: 0.9050 - precision: 0.9538 - recall: 0.9550 - val_loss: 0.1329 - val_iou_score: 0.8531 - val_precision: 0.9064 - val_recall: 0.9448 - lr: 2.5000e-04
# Epoch 89/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0599 - iou_score: 0.9050 - precision: 0.9541 - recall: 0.9545
# Epoch 89: val_iou_score improved from 0.85311 to 0.85507, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0599 - iou_score: 0.9050 - precision: 0.9541 - recall: 0.9545 - val_loss: 0.1312 - val_iou_score: 0.8551 - val_precision: 0.9165 - val_recall: 0.9338 - lr: 2.5000e-04
# Epoch 90/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0581 - iou_score: 0.9072 - precision: 0.9544 - recall: 0.9560
# Epoch 90: val_iou_score did not improve from 0.85507
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0581 - iou_score: 0.9072 - precision: 0.9544 - recall: 0.9560 - val_loss: 0.1491 - val_iou_score: 0.8529 - val_precision: 0.9158 - val_recall: 0.9326 - lr: 2.5000e-04
# Epoch 91/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0597 - iou_score: 0.9066 - precision: 0.9546 - recall: 0.9543
# Epoch 91: val_iou_score did not improve from 0.85507
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0597 - iou_score: 0.9066 - precision: 0.9546 - recall: 0.9543 - val_loss: 0.1320 - val_iou_score: 0.8501 - val_precision: 0.9112 - val_recall: 0.9361 - lr: 2.5000e-04
# Epoch 92/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0592 - iou_score: 0.9060 - precision: 0.9534 - recall: 0.9555
# Epoch 92: val_iou_score did not improve from 0.85507
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0592 - iou_score: 0.9060 - precision: 0.9534 - recall: 0.9555 - val_loss: 0.1466 - val_iou_score: 0.8496 - val_precision: 0.9185 - val_recall: 0.9264 - lr: 2.5000e-04
# Epoch 93/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0598 - iou_score: 0.9057 - precision: 0.9556 - recall: 0.9520
# Epoch 93: val_iou_score improved from 0.85507 to 0.85922, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 81ms/step - loss: 0.0598 - iou_score: 0.9057 - precision: 0.9556 - recall: 0.9520 - val_loss: 0.1223 - val_iou_score: 0.8592 - val_precision: 0.9130 - val_recall: 0.9436 - lr: 2.5000e-04
# Epoch 94/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0553 - iou_score: 0.9130 - precision: 0.9598 - recall: 0.9551
# Epoch 94: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0553 - iou_score: 0.9130 - precision: 0.9598 - recall: 0.9551 - val_loss: 0.1738 - val_iou_score: 0.8471 - val_precision: 0.9179 - val_recall: 0.9245 - lr: 2.5000e-04
# Epoch 95/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0584 - iou_score: 0.9138 - precision: 0.9609 - recall: 0.9546
# Epoch 95: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 5s 73ms/step - loss: 0.0584 - iou_score: 0.9138 - precision: 0.9609 - recall: 0.9546 - val_loss: 0.1373 - val_iou_score: 0.8533 - val_precision: 0.9204 - val_recall: 0.9265 - lr: 2.5000e-04
# Epoch 96/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0540 - iou_score: 0.9168 - precision: 0.9606 - recall: 0.9585
# Epoch 96: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0540 - iou_score: 0.9168 - precision: 0.9606 - recall: 0.9585 - val_loss: 0.1346 - val_iou_score: 0.8552 - val_precision: 0.9144 - val_recall: 0.9372 - lr: 2.5000e-04
# Epoch 97/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0542 - iou_score: 0.9146 - precision: 0.9596 - recall: 0.9590
# Epoch 97: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0542 - iou_score: 0.9146 - precision: 0.9596 - recall: 0.9590 - val_loss: 0.1368 - val_iou_score: 0.8589 - val_precision: 0.9213 - val_recall: 0.9327 - lr: 2.5000e-04
# Epoch 98/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0510 - iou_score: 0.9199 - precision: 0.9631 - recall: 0.9597
# Epoch 98: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 75ms/step - loss: 0.0510 - iou_score: 0.9199 - precision: 0.9631 - recall: 0.9597 - val_loss: 0.1376 - val_iou_score: 0.8583 - val_precision: 0.9081 - val_recall: 0.9471 - lr: 2.5000e-04
# Epoch 99/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0525 - iou_score: 0.9184 - precision: 0.9628 - recall: 0.9584
# Epoch 99: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0525 - iou_score: 0.9184 - precision: 0.9628 - recall: 0.9584 - val_loss: 0.1456 - val_iou_score: 0.8571 - val_precision: 0.9102 - val_recall: 0.9435 - lr: 2.5000e-04
# Epoch 100/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0508 - iou_score: 0.9198 - precision: 0.9635 - recall: 0.9589
# Epoch 100: val_iou_score did not improve from 0.85922
# 75/75 [==============================] - 6s 74ms/step - loss: 0.0508 - iou_score: 0.9198 - precision: 0.9635 - recall: 0.9589 - val_loss: 0.1469 - val_iou_score: 0.8573 - val_precision: 0.9083 - val_recall: 0.9464 - lr: 2.5000e-04
# Epoch 101/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0494 - iou_score: 0.9231 - precision: 0.9648 - recall: 0.9611
# Epoch 101: val_iou_score improved from 0.85922 to 0.86825, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_256x256_F_NUM_128_DT_09_May_11h42min_fold_1.h5
# 75/75 [==============================] - 6s 82ms/step - loss: 0.0494 - iou_score: 0.9231 - precision: 0.9648 - recall: 0.9611 - val_loss: 0.1285 - val_iou_score: 0.8683 - val_precision: 0.9173 - val_recall: 0.9475 - lr: 2.5000e-04
# Epoch 102/250
# 75/75 [==============================] - ETA: 0s - loss: 0.0471 - iou_score: 0.9264 - precision: 0.9657 - recall: 0.9633
# Epoch 102: val_iou_score did not improve from 0.86825
# ...
# Epoch 214: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 78ms/step - loss: 0.0119 - iou_score: 0.9823 - precision: 0.9921 - recall: 0.9911 - val_loss: 1.1045 - val_iou_score: 0.8654 - val_precision: 0.9363 - val_recall: 0.9209 - lr: 7.8125e-06
# Epoch 215/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0119 - iou_score: 0.9824 - precision: 0.9921 - recall: 0.9912
# Epoch 215: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 77ms/step - loss: 0.0119 - iou_score: 0.9824 - precision: 0.9921 - recall: 0.9912 - val_loss: 1.1096 - val_iou_score: 0.8654 - val_precision: 0.9363 - val_recall: 0.9209 - lr: 7.8125e-06
# Epoch 216/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0118 - iou_score: 0.9825 - precision: 0.9921 - recall: 0.9913
# Epoch 216: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 77ms/step - loss: 0.0118 - iou_score: 0.9825 - precision: 0.9921 - recall: 0.9913 - val_loss: 1.1131 - val_iou_score: 0.8653 - val_precision: 0.9362 - val_recall: 0.9209 - lr: 7.8125e-06
# Epoch 217/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0118 - iou_score: 0.9826 - precision: 0.9922 - recall: 0.9913
# Epoch 217: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 217: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0118 - iou_score: 0.9826 - precision: 0.9922 - recall: 0.9913 - val_loss: 1.1188 - val_iou_score: 0.8653 - val_precision: 0.9362 - val_recall: 0.9209 - lr: 7.8125e-06
# Epoch 218/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9914
# Epoch 218: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9914 - val_loss: 1.1216 - val_iou_score: 0.8652 - val_precision: 0.9362 - val_recall: 0.9208 - lr: 3.9063e-06
# Epoch 219/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9913
# Epoch 219: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9913 - val_loss: 1.1257 - val_iou_score: 0.8652 - val_precision: 0.9363 - val_recall: 0.9207 - lr: 3.9063e-06
# Epoch 220/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9913
# Epoch 220: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0117 - iou_score: 0.9827 - precision: 0.9922 - recall: 0.9913 - val_loss: 1.1285 - val_iou_score: 0.8651 - val_precision: 0.9363 - val_recall: 0.9206 - lr: 3.9063e-06
# Epoch 221/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914
# Epoch 221: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914 - val_loss: 1.1310 - val_iou_score: 0.8651 - val_precision: 0.9363 - val_recall: 0.9205 - lr: 3.9063e-06
# Epoch 222/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915
# Epoch 222: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1334 - val_iou_score: 0.8651 - val_precision: 0.9363 - val_recall: 0.9205 - lr: 3.9063e-06
# Epoch 223/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915
# Epoch 223: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 78ms/step - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1356 - val_iou_score: 0.8651 - val_precision: 0.9363 - val_recall: 0.9205 - lr: 3.9063e-06
# Epoch 224/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915
# Epoch 224: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 7s 89ms/step - loss: 0.0116 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1380 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 3.9063e-06
# Epoch 225/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0116 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915
# Epoch 225: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 7s 90ms/step - loss: 0.0116 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1398 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 3.9063e-06
# Epoch 226/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914
# Epoch 226: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 7s 91ms/step - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914 - val_loss: 1.1418 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 3.9063e-06
# Epoch 227/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914
# Epoch 227: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 227: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 85ms/step - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9914 - val_loss: 1.1442 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 3.9063e-06
# Epoch 228/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915
# Epoch 228: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 81ms/step - loss: 0.0115 - iou_score: 0.9828 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1448 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 229/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9923 - recall: 0.9915
# Epoch 229: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 80ms/step - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1454 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 230/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9923 - recall: 0.9915
# Epoch 230: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9923 - recall: 0.9915 - val_loss: 1.1458 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 231/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 231: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 77ms/step - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1471 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 232/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 232: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1482 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 233/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915
# Epoch 233: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 77ms/step - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1486 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.9531e-06
# Epoch 234/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 234: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 81ms/step - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1490 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9203 - lr: 1.9531e-06
# Epoch 235/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915
# Epoch 235: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 80ms/step - loss: 0.0114 - iou_score: 0.9829 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1502 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9203 - lr: 1.9531e-06
# Epoch 236/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 236: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 77ms/step - loss: 0.0113 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1514 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9203 - lr: 1.9531e-06
# Epoch 237/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 237: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 237: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 78ms/step - loss: 0.0113 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1524 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9203 - lr: 1.9531e-06
# Epoch 238/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 238: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1525 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 239/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 239: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1531 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 240/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916
# Epoch 240: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1534 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 241/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 241: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1538 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 242/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 242: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1541 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 243/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 243: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1544 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 244/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915
# Epoch 244: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0114 - iou_score: 0.9830 - precision: 0.9924 - recall: 0.9915 - val_loss: 1.1547 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 245/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 245: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1550 - val_iou_score: 0.8650 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 246/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916
# Epoch 246: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1547 - val_iou_score: 0.8649 - val_precision: 0.9363 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 247/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916
# Epoch 247: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0113 - iou_score: 0.9832 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1552 - val_iou_score: 0.8649 - val_precision: 0.9362 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 248/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 248: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1555 - val_iou_score: 0.8649 - val_precision: 0.9362 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 249/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 249: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1560 - val_iou_score: 0.8649 - val_precision: 0.9362 - val_recall: 0.9204 - lr: 1.0000e-06
# Epoch 250/250
# 76/76 [==============================] - ETA: 0s - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916
# Epoch 250: val_iou_score did not improve from 0.86687
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0113 - iou_score: 0.9831 - precision: 0.9924 - recall: 0.9916 - val_loss: 1.1566 - val_iou_score: 0.8650 - val_precision: 0.9362 - val_recall: 0.9204 - lr: 1.0000e-06
# Training Metrics
#  IoU = 98.37 %
#  Precision = 99.26 %
#  Recall = 99.17 %
# Validation Metrics
#  IoU = 86.50 %
#  Recall = 93.62 %
#  Precision = 92.04 %
# After fold training, learning rate reposition from 9.999999974752427e-07 to 0,001

# %%
# training set results
iou_train = [vc_sc_train[i][1] for i in range(len(vc_sc_train))]
precision_train = [vc_sc_train[i][2] for i in range(len(vc_sc_train))]
recall_train = [vc_sc_train[i][3] for i in range(len(vc_sc_train))]
print("Summary of Training Set Results")
print(f'Average IoU = {np.mean(iou_train)*100:.2f} ± {np.std(iou_train)*100:.2f} %')
print(f'Average Precision = {np.mean(precision_train)*100:.2f} ± {np.std(precision_train)*100:.2f} %')
print(f'Average Recall = {np.mean(recall_train)*100:.2f} ± {np.std(recall_train)*100:.2f} %')

# validation set results
iou_valid = [vc_sc_valid[i][1] for i in range(len(vc_sc_valid))]
precision_valid = [vc_sc_valid[i][2] for i in range(len(vc_sc_valid))]
recall_valid = [vc_sc_valid[i][3] for i in range(len(vc_sc_valid))]
print("\nSummary of Validation Set Results")
print(f'Average IoU = {np.mean(iou_valid)*100:.2f} ± {np.std(iou_valid)*100:.2f} %')
print(f'Average Precision = {np.mean(precision_valid)*100:.2f} ± {np.std(precision_valid)*100:.2f} %')
print(f'Average Recall = {np.mean(recall_valid)*100:.2f} ± {np.std(recall_valid)*100:.2f} %')
# Out:
# Summary of Training Set Results
# Average IoU = 98.48 ± 0.33 %
# Average Precision = 99.30 ± 0.15 %
# Average Recall = 99.23 ± 0.18 %
#
# Summary of Validation Set Results
# Average IoU = 88.18 ± 1.27 %
# Average Precision = 94.23 ± 0.56 %
# Average Recall = 93.33 ± 0.92 %

# %% [markdown]
# ### Cross Validation Plots

# %%
metrics_graphs(histories[0], model=model, model_conf= "U_Net_RED_CV_Fold_#1", metrics=['loss', 'iou_score'], y_log=True)

# %%
metrics_graphs(histories[1], model=model, model_conf= "U_Net_RED_CV_Fold_#2", metrics=['loss', 'iou_score'], y_log=True)

# %%
metrics_graphs(histories[2], model=model, model_conf= "U_Net_RED_CV_Fold_#3", metrics=['loss', 'iou_score'], y_log=True)

# %% [markdown]
# ## Re-Train the model on the entire training set

# %%
# redifines learning rate
lr_atual = model.optimizer.lr.read_value()
if lr_atual != 0.001:
    print(f'After fold training, learning rate reposition from {lr_atual} to 0,001')
    model.optimizer.lr.assign(0.001)
    
# Create string run and callback functions
str_run = create_run_string(model_name='unet_red', use_cross_val=False)
print(str_run)
cllbcks = callback_funcs(str_run, mode='min', monitor_metric='loss')

# Create data generators for training and validation sets
generator_train = generate_batch([np.array(imgs_path_train_red), 
                                  np.array(msks_paths)], 
                                  batch_size=CONFIGS["BATCH_SZ"])

# Create and compile the U-Net model
model = None
model = create_UNET_RED(img_dim= (CONFIGS['H'], CONFIGS['W']), 
                    ref_filters=CONFIGS['REF_FILTERS'], 
                    batch_sz=CONFIGS['BATCH_SZ'])

model.compile(optimizer=CONFIGS['OPTIMIZER'], 
                loss='binary_crossentropy', 
                metrics=CONFIGS['METRICS'])

# Train the model
history = model.fit(generator_train,
                    epochs=CONFIGS['EPOCHS'],
                    batch_size=CONFIGS['BATCH_SZ'],
                    verbose=1,
                    steps_per_epoch= len(imgs_path_train_red) // CONFIGS['BATCH_SZ'],
                    callbacks=cllbcks)


score_test = model.evaluate(generator_test, 
                           steps = len(imgs_path_test_red) // CONFIGS['BATCH_SZ'], 
                           verbose = 0)
# Out:
# After fold training, learning rate reposition from 9.999999974752427e-07 to 0,001
# unet_red_256x256_F_NUM_128_DT_09_May_14h32min
# Epoch 1/250
# 113/113 [==============================] - ETA: 0s - loss: 0.5907 - iou_score: 0.0264 - precision: 0.4127 - recall: 0.0692
# Epoch 1: loss improved from inf to 0.59068, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 12s 89ms/step - loss: 0.5907 - iou_score: 0.0264 - precision: 0.4127 - recall: 0.0692 - lr: 0.0010
# Epoch 2/250
# 113/113 [==============================] - ETA: 0s - loss: 0.5114 - iou_score: 0.1529 - precision: 0.6006 - recall: 0.3005
# Epoch 2: loss improved from 0.59068 to 0.51145, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 90ms/step - loss: 0.5114 - iou_score: 0.1529 - precision: 0.6006 - recall: 0.3005 - lr: 0.0010
# Epoch 3/250
# 113/113 [==============================] - ETA: 0s - loss: 0.4139 - iou_score: 0.3433 - precision: 0.6877 - recall: 0.5857
# Epoch 3: loss improved from 0.51145 to 0.41388, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.4139 - iou_score: 0.3433 - precision: 0.6877 - recall: 0.5857 - lr: 0.0010
# Epoch 4/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2766 - iou_score: 0.5564 - precision: 0.8839 - recall: 0.6928
# Epoch 4: loss improved from 0.41388 to 0.27658, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 0.2766 - iou_score: 0.5564 - precision: 0.8839 - recall: 0.6928 - lr: 0.0010
# Epoch 5/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2414 - iou_score: 0.6914 - precision: 0.8832 - recall: 0.7855
# Epoch 5: loss improved from 0.27658 to 0.24139, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.2414 - iou_score: 0.6914 - precision: 0.8832 - recall: 0.7855 - lr: 0.0010
# Epoch 6/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2134 - iou_score: 0.6883 - precision: 0.8929 - recall: 0.8017
# Epoch 6: loss improved from 0.24139 to 0.21337, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.2134 - iou_score: 0.6883 - precision: 0.8929 - recall: 0.8017 - lr: 0.0010
# Epoch 7/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2356 - iou_score: 0.7110 - precision: 0.8733 - recall: 0.8176
# Epoch 7: loss did not improve from 0.21337
# 113/113 [==============================] - 8s 66ms/step - loss: 0.2356 - iou_score: 0.7110 - precision: 0.8733 - recall: 0.8176 - lr: 0.0010
# Epoch 8/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2165 - iou_score: 0.7128 - precision: 0.8831 - recall: 0.8198
# Epoch 8: loss did not improve from 0.21337
# 113/113 [==============================] - 7s 66ms/step - loss: 0.2165 - iou_score: 0.7128 - precision: 0.8831 - recall: 0.8198 - lr: 0.0010
# Epoch 9/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1965 - iou_score: 0.7188 - precision: 0.8835 - recall: 0.8250
# Epoch 9: loss improved from 0.21337 to 0.19650, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.1965 - iou_score: 0.7188 - precision: 0.8835 - recall: 0.8250 - lr: 0.0010
# Epoch 10/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1986 - iou_score: 0.7235 - precision: 0.8783 - recall: 0.8358
# Epoch 10: loss did not improve from 0.19650
# 113/113 [==============================] - 8s 66ms/step - loss: 0.1986 - iou_score: 0.7235 - precision: 0.8783 - recall: 0.8358 - lr: 0.0010
# Epoch 11/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2121 - iou_score: 0.7128 - precision: 0.8695 - recall: 0.8302
# Epoch 11: loss did not improve from 0.19650
# 113/113 [==============================] - 8s 66ms/step - loss: 0.2121 - iou_score: 0.7128 - precision: 0.8695 - recall: 0.8302 - lr: 0.0010
# Epoch 12/250
# 113/113 [==============================] - ETA: 0s - loss: 0.2022 - iou_score: 0.7327 - precision: 0.8716 - recall: 0.8529
# Epoch 12: loss did not improve from 0.19650
# 113/113 [==============================] - 8s 69ms/step - loss: 0.2022 - iou_score: 0.7327 - precision: 0.8716 - recall: 0.8529 - lr: 0.0010
# Epoch 13/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1938 - iou_score: 0.7380 - precision: 0.8703 - recall: 0.8542
# Epoch 13: loss improved from 0.19650 to 0.19377, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.1938 - iou_score: 0.7380 - precision: 0.8703 - recall: 0.8542 - lr: 0.0010
# Epoch 14/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1928 - iou_score: 0.7494 - precision: 0.8752 - recall: 0.8666
# Epoch 14: loss improved from 0.19377 to 0.19280, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 0.1928 - iou_score: 0.7494 - precision: 0.8752 - recall: 0.8666 - lr: 0.0010
# Epoch 15/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1943 - iou_score: 0.7587 - precision: 0.8775 - recall: 0.8730
# Epoch 15: loss did not improve from 0.19280
# 113/113 [==============================] - 8s 67ms/step - loss: 0.1943 - iou_score: 0.7587 - precision: 0.8775 - recall: 0.8730 - lr: 0.0010
# Epoch 16/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1938 - iou_score: 0.7501 - precision: 0.8762 - recall: 0.8667
# Epoch 16: loss did not improve from 0.19280
# 113/113 [==============================] - 8s 67ms/step - loss: 0.1938 - iou_score: 0.7501 - precision: 0.8762 - recall: 0.8667 - lr: 0.0010
# Epoch 17/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1768 - iou_score: 0.7588 - precision: 0.8796 - recall: 0.8712
# Epoch 17: loss improved from 0.19280 to 0.17682, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.1768 - iou_score: 0.7588 - precision: 0.8796 - recall: 0.8712 - lr: 0.0010
# Epoch 18/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1826 - iou_score: 0.7623 - precision: 0.8864 - recall: 0.8711
# Epoch 18: loss did not improve from 0.17682
# 113/113 [==============================] - 8s 67ms/step - loss: 0.1826 - iou_score: 0.7623 - precision: 0.8864 - recall: 0.8711 - lr: 0.0010
# Epoch 19/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1646 - iou_score: 0.7803 - precision: 0.8924 - recall: 0.8814
# Epoch 19: loss improved from 0.17682 to 0.16463, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 0.1646 - iou_score: 0.7803 - precision: 0.8924 - recall: 0.8814 - lr: 0.0010
# Epoch 20/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1594 - iou_score: 0.7836 - precision: 0.8922 - recall: 0.8871
# Epoch 20: loss improved from 0.16463 to 0.15937, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 90ms/step - loss: 0.1594 - iou_score: 0.7836 - precision: 0.8922 - recall: 0.8871 - lr: 0.0010
# Epoch 21/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1612 - iou_score: 0.7820 - precision: 0.8978 - recall: 0.8858
# Epoch 21: loss did not improve from 0.15937
# 113/113 [==============================] - 7s 65ms/step - loss: 0.1612 - iou_score: 0.7820 - precision: 0.8978 - recall: 0.8858 - lr: 0.0010
# Epoch 22/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1513 - iou_score: 0.7954 - precision: 0.8933 - recall: 0.8966
# Epoch 22: loss improved from 0.15937 to 0.15128, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.1513 - iou_score: 0.7954 - precision: 0.8933 - recall: 0.8966 - lr: 0.0010
# Epoch 23/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1523 - iou_score: 0.7933 - precision: 0.9021 - recall: 0.8918
# Epoch 23: loss did not improve from 0.15128
# 113/113 [==============================] - 7s 64ms/step - loss: 0.1523 - iou_score: 0.7933 - precision: 0.9021 - recall: 0.8918 - lr: 0.0010
# Epoch 24/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1397 - iou_score: 0.8048 - precision: 0.9062 - recall: 0.8994
# Epoch 24: loss improved from 0.15128 to 0.13974, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.1397 - iou_score: 0.8048 - precision: 0.9062 - recall: 0.8994 - lr: 0.0010
# Epoch 25/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1420 - iou_score: 0.8108 - precision: 0.9082 - recall: 0.9023
# Epoch 25: loss did not improve from 0.13974
# 113/113 [==============================] - 7s 64ms/step - loss: 0.1420 - iou_score: 0.8108 - precision: 0.9082 - recall: 0.9023 - lr: 0.0010
# Epoch 26/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1313 - iou_score: 0.8128 - precision: 0.9186 - recall: 0.8983
# Epoch 26: loss improved from 0.13974 to 0.13131, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.1313 - iou_score: 0.8128 - precision: 0.9186 - recall: 0.8983 - lr: 0.0010
# Epoch 27/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1324 - iou_score: 0.8144 - precision: 0.9159 - recall: 0.9036
# Epoch 27: loss did not improve from 0.13131
# 113/113 [==============================] - 7s 65ms/step - loss: 0.1324 - iou_score: 0.8144 - precision: 0.9159 - recall: 0.9036 - lr: 0.0010
# Epoch 28/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1403 - iou_score: 0.8259 - precision: 0.9135 - recall: 0.9117
# Epoch 28: loss did not improve from 0.13131
# 113/113 [==============================] - 8s 68ms/step - loss: 0.1403 - iou_score: 0.8259 - precision: 0.9135 - recall: 0.9117 - lr: 0.0010
# Epoch 29/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1326 - iou_score: 0.8185 - precision: 0.9199 - recall: 0.9004
# Epoch 29: loss did not improve from 0.13131
# 113/113 [==============================] - 7s 66ms/step - loss: 0.1326 - iou_score: 0.8185 - precision: 0.9199 - recall: 0.9004 - lr: 0.0010
# Epoch 30/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1241 - iou_score: 0.8204 - precision: 0.9185 - recall: 0.9108
# Epoch 30: loss improved from 0.13131 to 0.12410, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.1241 - iou_score: 0.8204 - precision: 0.9185 - recall: 0.9108 - lr: 0.0010
# Epoch 31/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1223 - iou_score: 0.8316 - precision: 0.9181 - recall: 0.9187
# Epoch 31: loss improved from 0.12410 to 0.12229, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.1223 - iou_score: 0.8316 - precision: 0.9181 - recall: 0.9187 - lr: 0.0010
# Epoch 32/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1174 - iou_score: 0.8403 - precision: 0.9226 - recall: 0.9205
# Epoch 32: loss improved from 0.12229 to 0.11737, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.1174 - iou_score: 0.8403 - precision: 0.9226 - recall: 0.9205 - lr: 0.0010
# Epoch 33/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1116 - iou_score: 0.8429 - precision: 0.9232 - recall: 0.9226
# Epoch 33: loss improved from 0.11737 to 0.11155, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.1116 - iou_score: 0.8429 - precision: 0.9232 - recall: 0.9226 - lr: 0.0010
# Epoch 34/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1083 - iou_score: 0.8477 - precision: 0.9275 - recall: 0.9243
# Epoch 34: loss improved from 0.11155 to 0.10832, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.1083 - iou_score: 0.8477 - precision: 0.9275 - recall: 0.9243 - lr: 0.0010
# Epoch 35/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1059 - iou_score: 0.8504 - precision: 0.9258 - recall: 0.9284
# Epoch 35: loss improved from 0.10832 to 0.10594, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.1059 - iou_score: 0.8504 - precision: 0.9258 - recall: 0.9284 - lr: 0.0010
# Epoch 36/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1027 - iou_score: 0.8552 - precision: 0.9309 - recall: 0.9267
# Epoch 36: loss improved from 0.10594 to 0.10273, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 90ms/step - loss: 0.1027 - iou_score: 0.8552 - precision: 0.9309 - recall: 0.9267 - lr: 0.0010
# Epoch 37/250
# 113/113 [==============================] - ETA: 0s - loss: 0.1025 - iou_score: 0.8581 - precision: 0.9301 - recall: 0.9307
# Epoch 37: loss improved from 0.10273 to 0.10254, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.1025 - iou_score: 0.8581 - precision: 0.9301 - recall: 0.9307 - lr: 0.0010
# Epoch 38/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0917 - iou_score: 0.8661 - precision: 0.9372 - recall: 0.9331
# Epoch 38: loss improved from 0.10254 to 0.09170, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0917 - iou_score: 0.8661 - precision: 0.9372 - recall: 0.9331 - lr: 0.0010
# Epoch 39/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0938 - iou_score: 0.8654 - precision: 0.9382 - recall: 0.9317
# Epoch 39: loss did not improve from 0.09170
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0938 - iou_score: 0.8654 - precision: 0.9382 - recall: 0.9317 - lr: 0.0010
# Epoch 40/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0932 - iou_score: 0.8623 - precision: 0.9402 - recall: 0.9284
# Epoch 40: loss did not improve from 0.09170
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0932 - iou_score: 0.8623 - precision: 0.9402 - recall: 0.9284 - lr: 0.0010
# Epoch 41/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0880 - iou_score: 0.8758 - precision: 0.9422 - recall: 0.9380
# Epoch 41: loss improved from 0.09170 to 0.08805, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0880 - iou_score: 0.8758 - precision: 0.9422 - recall: 0.9380 - lr: 0.0010
# Epoch 42/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0837 - iou_score: 0.8814 - precision: 0.9437 - recall: 0.9415
# Epoch 42: loss improved from 0.08805 to 0.08373, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0837 - iou_score: 0.8814 - precision: 0.9437 - recall: 0.9415 - lr: 0.0010
# Epoch 43/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0881 - iou_score: 0.8742 - precision: 0.9426 - recall: 0.9344
# Epoch 43: loss did not improve from 0.08373
# 113/113 [==============================] - 8s 67ms/step - loss: 0.0881 - iou_score: 0.8742 - precision: 0.9426 - recall: 0.9344 - lr: 0.0010
# Epoch 44/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0834 - iou_score: 0.8785 - precision: 0.9422 - recall: 0.9407
# Epoch 44: loss improved from 0.08373 to 0.08345, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0834 - iou_score: 0.8785 - precision: 0.9422 - recall: 0.9407 - lr: 0.0010
# Epoch 45/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0819 - iou_score: 0.8862 - precision: 0.9486 - recall: 0.9412
# Epoch 45: loss improved from 0.08345 to 0.08192, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 92ms/step - loss: 0.0819 - iou_score: 0.8862 - precision: 0.9486 - recall: 0.9412 - lr: 0.0010
# Epoch 46/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0754 - iou_score: 0.8941 - precision: 0.9519 - recall: 0.9456
# Epoch 46: loss improved from 0.08192 to 0.07544, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 0.0754 - iou_score: 0.8941 - precision: 0.9519 - recall: 0.9456 - lr: 0.0010
# Epoch 47/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0745 - iou_score: 0.8927 - precision: 0.9527 - recall: 0.9433
# Epoch 47: loss improved from 0.07544 to 0.07445, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 90ms/step - loss: 0.0745 - iou_score: 0.8927 - precision: 0.9527 - recall: 0.9433 - lr: 0.0010
# Epoch 48/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0728 - iou_score: 0.8943 - precision: 0.9516 - recall: 0.9447
# Epoch 48: loss improved from 0.07445 to 0.07278, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0728 - iou_score: 0.8943 - precision: 0.9516 - recall: 0.9447 - lr: 0.0010
# Epoch 49/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0772 - iou_score: 0.8862 - precision: 0.9477 - recall: 0.9436
# Epoch 49: loss did not improve from 0.07278
# 113/113 [==============================] - 7s 66ms/step - loss: 0.0772 - iou_score: 0.8862 - precision: 0.9477 - recall: 0.9436 - lr: 0.0010
# Epoch 50/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0749 - iou_score: 0.8887 - precision: 0.9516 - recall: 0.9433
# Epoch 50: loss did not improve from 0.07278
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0749 - iou_score: 0.8887 - precision: 0.9516 - recall: 0.9433 - lr: 0.0010
# Epoch 51/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0719 - iou_score: 0.8900 - precision: 0.9524 - recall: 0.9422
# Epoch 51: loss improved from 0.07278 to 0.07189, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0719 - iou_score: 0.8900 - precision: 0.9524 - recall: 0.9422 - lr: 0.0010
# Epoch 52/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0648 - iou_score: 0.9036 - precision: 0.9559 - recall: 0.9511
# Epoch 52: loss improved from 0.07189 to 0.06477, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0648 - iou_score: 0.9036 - precision: 0.9559 - recall: 0.9511 - lr: 0.0010
# Epoch 53/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0634 - iou_score: 0.9062 - precision: 0.9583 - recall: 0.9501
# Epoch 53: loss improved from 0.06477 to 0.06339, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0634 - iou_score: 0.9062 - precision: 0.9583 - recall: 0.9501 - lr: 0.0010
# Epoch 54/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0600 - iou_score: 0.9115 - precision: 0.9599 - recall: 0.9528
# Epoch 54: loss improved from 0.06339 to 0.06002, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0600 - iou_score: 0.9115 - precision: 0.9599 - recall: 0.9528 - lr: 0.0010
# Epoch 55/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0587 - iou_score: 0.9145 - precision: 0.9603 - recall: 0.9552
# Epoch 55: loss improved from 0.06002 to 0.05866, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0587 - iou_score: 0.9145 - precision: 0.9603 - recall: 0.9552 - lr: 0.0010
# Epoch 56/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0600 - iou_score: 0.9133 - precision: 0.9600 - recall: 0.9530
# Epoch 56: loss did not improve from 0.05866
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0600 - iou_score: 0.9133 - precision: 0.9600 - recall: 0.9530 - lr: 0.0010
# Epoch 57/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0577 - iou_score: 0.9132 - precision: 0.9607 - recall: 0.9555
# Epoch 57: loss improved from 0.05866 to 0.05775, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0577 - iou_score: 0.9132 - precision: 0.9607 - recall: 0.9555 - lr: 0.0010
# Epoch 58/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0526 - iou_score: 0.9222 - precision: 0.9642 - recall: 0.9589
# Epoch 58: loss improved from 0.05775 to 0.05260, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 0.0526 - iou_score: 0.9222 - precision: 0.9642 - recall: 0.9589 - lr: 0.0010
# Epoch 59/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0511 - iou_score: 0.9250 - precision: 0.9655 - recall: 0.9603
# Epoch 59: loss improved from 0.05260 to 0.05106, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0511 - iou_score: 0.9250 - precision: 0.9655 - recall: 0.9603 - lr: 0.0010
# Epoch 60/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0564 - iou_score: 0.9196 - precision: 0.9629 - recall: 0.9558
# Epoch 60: loss did not improve from 0.05106
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0564 - iou_score: 0.9196 - precision: 0.9629 - recall: 0.9558 - lr: 0.0010
# Epoch 61/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0520 - iou_score: 0.9257 - precision: 0.9654 - recall: 0.9598
# Epoch 61: loss did not improve from 0.05106
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0520 - iou_score: 0.9257 - precision: 0.9654 - recall: 0.9598 - lr: 0.0010
# Epoch 62/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0510 - iou_score: 0.9274 - precision: 0.9664 - recall: 0.9613
# Epoch 62: loss improved from 0.05106 to 0.05103, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0510 - iou_score: 0.9274 - precision: 0.9664 - recall: 0.9613 - lr: 0.0010
# Epoch 63/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0502 - iou_score: 0.9268 - precision: 0.9651 - recall: 0.9636
# Epoch 63: loss improved from 0.05103 to 0.05015, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 84ms/step - loss: 0.0502 - iou_score: 0.9268 - precision: 0.9651 - recall: 0.9636 - lr: 0.0010
# Epoch 64/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0470 - iou_score: 0.9326 - precision: 0.9678 - recall: 0.9639
# Epoch 64: loss improved from 0.05015 to 0.04704, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 0.0470 - iou_score: 0.9326 - precision: 0.9678 - recall: 0.9639 - lr: 0.0010
# Epoch 65/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0473 - iou_score: 0.9319 - precision: 0.9684 - recall: 0.9625
# Epoch 65: loss did not improve from 0.04704
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0473 - iou_score: 0.9319 - precision: 0.9684 - recall: 0.9625 - lr: 0.0010
# Epoch 66/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0480 - iou_score: 0.9320 - precision: 0.9679 - recall: 0.9632
# Epoch 66: loss did not improve from 0.04704
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0480 - iou_score: 0.9320 - precision: 0.9679 - recall: 0.9632 - lr: 0.0010
# Epoch 67/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0467 - iou_score: 0.9324 - precision: 0.9683 - recall: 0.9636
# Epoch 67: loss improved from 0.04704 to 0.04673, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0467 - iou_score: 0.9324 - precision: 0.9683 - recall: 0.9636 - lr: 0.0010
# Epoch 68/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0464 - iou_score: 0.9338 - precision: 0.9680 - recall: 0.9645
# Epoch 68: loss improved from 0.04673 to 0.04644, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 93ms/step - loss: 0.0464 - iou_score: 0.9338 - precision: 0.9680 - recall: 0.9645 - lr: 0.0010
# Epoch 69/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0481 - iou_score: 0.9306 - precision: 0.9676 - recall: 0.9636
# Epoch 69: loss did not improve from 0.04644
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0481 - iou_score: 0.9306 - precision: 0.9676 - recall: 0.9636 - lr: 0.0010
# Epoch 70/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0445 - iou_score: 0.9368 - precision: 0.9696 - recall: 0.9667
# Epoch 70: loss improved from 0.04644 to 0.04453, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0445 - iou_score: 0.9368 - precision: 0.9696 - recall: 0.9667 - lr: 0.0010
# Epoch 71/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0425 - iou_score: 0.9404 - precision: 0.9718 - recall: 0.9683
# Epoch 71: loss improved from 0.04453 to 0.04252, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0425 - iou_score: 0.9404 - precision: 0.9718 - recall: 0.9683 - lr: 0.0010
# Epoch 72/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0397 - iou_score: 0.9429 - precision: 0.9717 - recall: 0.9713
# Epoch 72: loss improved from 0.04252 to 0.03975, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0397 - iou_score: 0.9429 - precision: 0.9717 - recall: 0.9713 - lr: 0.0010
# Epoch 73/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0388 - iou_score: 0.9435 - precision: 0.9733 - recall: 0.9708
# Epoch 73: loss improved from 0.03975 to 0.03880, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0388 - iou_score: 0.9435 - precision: 0.9733 - recall: 0.9708 - lr: 0.0010
# Epoch 74/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0361 - iou_score: 0.9477 - precision: 0.9749 - recall: 0.9729
# Epoch 74: loss improved from 0.03880 to 0.03606, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0361 - iou_score: 0.9477 - precision: 0.9749 - recall: 0.9729 - lr: 0.0010
# Epoch 75/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0352 - iou_score: 0.9489 - precision: 0.9754 - recall: 0.9737
# Epoch 75: loss improved from 0.03606 to 0.03516, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0352 - iou_score: 0.9489 - precision: 0.9754 - recall: 0.9737 - lr: 0.0010
# Epoch 76/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0348 - iou_score: 0.9496 - precision: 0.9761 - recall: 0.9735
# Epoch 76: loss improved from 0.03516 to 0.03478, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0348 - iou_score: 0.9496 - precision: 0.9761 - recall: 0.9735 - lr: 0.0010
# Epoch 77/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0346 - iou_score: 0.9496 - precision: 0.9751 - recall: 0.9745
# Epoch 77: loss improved from 0.03478 to 0.03459, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0346 - iou_score: 0.9496 - precision: 0.9751 - recall: 0.9745 - lr: 0.0010
# Epoch 78/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0344 - iou_score: 0.9500 - precision: 0.9754 - recall: 0.9745
# Epoch 78: loss improved from 0.03459 to 0.03442, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0344 - iou_score: 0.9500 - precision: 0.9754 - recall: 0.9745 - lr: 0.0010
# Epoch 79/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0341 - iou_score: 0.9505 - precision: 0.9762 - recall: 0.9740
# Epoch 79: loss improved from 0.03442 to 0.03407, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0341 - iou_score: 0.9505 - precision: 0.9762 - recall: 0.9740 - lr: 0.0010
# Epoch 80/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0324 - iou_score: 0.9528 - precision: 0.9769 - recall: 0.9760
# Epoch 80: loss improved from 0.03407 to 0.03243, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0324 - iou_score: 0.9528 - precision: 0.9769 - recall: 0.9760 - lr: 0.0010
# Epoch 81/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0325 - iou_score: 0.9527 - precision: 0.9769 - recall: 0.9761
# Epoch 81: loss did not improve from 0.03243
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0325 - iou_score: 0.9527 - precision: 0.9769 - recall: 0.9761 - lr: 0.0010
# Epoch 82/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0388 - iou_score: 0.9429 - precision: 0.9733 - recall: 0.9711
# Epoch 82: loss did not improve from 0.03243
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0388 - iou_score: 0.9429 - precision: 0.9733 - recall: 0.9711 - lr: 0.0010
# Epoch 83/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0337 - iou_score: 0.9501 - precision: 0.9761 - recall: 0.9748
# Epoch 83: loss did not improve from 0.03243
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0337 - iou_score: 0.9501 - precision: 0.9761 - recall: 0.9748 - lr: 0.0010
# Epoch 84/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0311 - iou_score: 0.9539 - precision: 0.9777 - recall: 0.9768
# Epoch 84: loss improved from 0.03243 to 0.03114, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0311 - iou_score: 0.9539 - precision: 0.9777 - recall: 0.9768 - lr: 0.0010
# Epoch 85/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0292 - iou_score: 0.9567 - precision: 0.9795 - recall: 0.9778
# Epoch 85: loss improved from 0.03114 to 0.02922, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0292 - iou_score: 0.9567 - precision: 0.9795 - recall: 0.9778 - lr: 0.0010
# Epoch 86/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0285 - iou_score: 0.9577 - precision: 0.9799 - recall: 0.9785
# Epoch 86: loss improved from 0.02922 to 0.02855, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0285 - iou_score: 0.9577 - precision: 0.9799 - recall: 0.9785 - lr: 0.0010
# Epoch 87/250
# 112/113 [============================>.] - ETA: 0s - loss: 0.0280 - iou_score: 0.9583 - precision: 0.9797 - recall: 0.9789
# Epoch 87: loss improved from 0.02855 to 0.02803, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0280 - iou_score: 0.9584 - precision: 0.9799 - recall: 0.9788 - lr: 0.0010
# Epoch 88/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0280 - iou_score: 0.9584 - precision: 0.9803 - recall: 0.9789
# Epoch 88: loss improved from 0.02803 to 0.02797, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0280 - iou_score: 0.9584 - precision: 0.9803 - recall: 0.9789 - lr: 0.0010
# Epoch 89/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0276 - iou_score: 0.9593 - precision: 0.9802 - recall: 0.9795
# Epoch 89: loss improved from 0.02797 to 0.02763, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 0.0276 - iou_score: 0.9593 - precision: 0.9802 - recall: 0.9795 - lr: 0.0010
# Epoch 90/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0268 - iou_score: 0.9602 - precision: 0.9812 - recall: 0.9797
# Epoch 90: loss improved from 0.02763 to 0.02680, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0268 - iou_score: 0.9602 - precision: 0.9812 - recall: 0.9797 - lr: 0.0010
# Epoch 91/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0273 - iou_score: 0.9594 - precision: 0.9807 - recall: 0.9796
# Epoch 91: loss did not improve from 0.02680
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0273 - iou_score: 0.9594 - precision: 0.9807 - recall: 0.9796 - lr: 0.0010
# Epoch 92/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0252 - iou_score: 0.9627 - precision: 0.9816 - recall: 0.9819
# Epoch 92: loss improved from 0.02680 to 0.02520, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0252 - iou_score: 0.9627 - precision: 0.9816 - recall: 0.9819 - lr: 0.0010
# Epoch 93/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0250 - iou_score: 0.9630 - precision: 0.9819 - recall: 0.9815
# Epoch 93: loss improved from 0.02520 to 0.02497, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0250 - iou_score: 0.9630 - precision: 0.9819 - recall: 0.9815 - lr: 0.0010
# Epoch 94/250
# 112/113 [============================>.] - ETA: 0s - loss: 0.0249 - iou_score: 0.9633 - precision: 0.9817 - recall: 0.9818
# Epoch 94: loss improved from 0.02497 to 0.02492, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0249 - iou_score: 0.9634 - precision: 0.9819 - recall: 0.9817 - lr: 0.0010
# Epoch 95/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0258 - iou_score: 0.9626 - precision: 0.9815 - recall: 0.9812
# Epoch 95: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0258 - iou_score: 0.9626 - precision: 0.9815 - recall: 0.9812 - lr: 0.0010
# Epoch 96/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0320 - iou_score: 0.9562 - precision: 0.9789 - recall: 0.9763
# Epoch 96: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0320 - iou_score: 0.9562 - precision: 0.9789 - recall: 0.9763 - lr: 0.0010
# Epoch 97/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0336 - iou_score: 0.9515 - precision: 0.9768 - recall: 0.9753
# Epoch 97: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0336 - iou_score: 0.9515 - precision: 0.9768 - recall: 0.9753 - lr: 0.0010
# Epoch 98/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0306 - iou_score: 0.9559 - precision: 0.9787 - recall: 0.9777
# Epoch 98: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0306 - iou_score: 0.9559 - precision: 0.9787 - recall: 0.9777 - lr: 0.0010
# Epoch 99/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0303 - iou_score: 0.9568 - precision: 0.9794 - recall: 0.9780
# Epoch 99: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0303 - iou_score: 0.9568 - precision: 0.9794 - recall: 0.9780 - lr: 0.0010
# Epoch 100/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0296 - iou_score: 0.9583 - precision: 0.9801 - recall: 0.9789
# Epoch 100: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0296 - iou_score: 0.9583 - precision: 0.9801 - recall: 0.9789 - lr: 0.0010
# Epoch 101/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0300 - iou_score: 0.9587 - precision: 0.9794 - recall: 0.9792
# Epoch 101: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0300 - iou_score: 0.9587 - precision: 0.9794 - recall: 0.9792 - lr: 0.0010
# Epoch 102/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0280 - iou_score: 0.9600 - precision: 0.9808 - recall: 0.9793
# Epoch 102: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0280 - iou_score: 0.9600 - precision: 0.9808 - recall: 0.9793 - lr: 0.0010
# Epoch 103/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0272 - iou_score: 0.9606 - precision: 0.9811 - recall: 0.9797
# Epoch 103: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 103: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0272 - iou_score: 0.9606 - precision: 0.9811 - recall: 0.9797 - lr: 0.0010
# Epoch 104/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0271 - iou_score: 0.9613 - precision: 0.9810 - recall: 0.9803
# Epoch 104: loss did not improve from 0.02492
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0271 - iou_score: 0.9613 - precision: 0.9810 - recall: 0.9803 - lr: 5.0000e-04
# Epoch 105/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0210 - iou_score: 0.9693 - precision: 0.9849 - recall: 0.9847
# Epoch 105: loss improved from 0.02492 to 0.02103, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0210 - iou_score: 0.9693 - precision: 0.9849 - recall: 0.9847 - lr: 5.0000e-04
# Epoch 106/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0189 - iou_score: 0.9723 - precision: 0.9864 - recall: 0.9862
# Epoch 106: loss improved from 0.02103 to 0.01888, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0189 - iou_score: 0.9723 - precision: 0.9864 - recall: 0.9862 - lr: 5.0000e-04
# Epoch 107/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0181 - iou_score: 0.9733 - precision: 0.9871 - recall: 0.9865
# Epoch 107: loss improved from 0.01888 to 0.01808, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0181 - iou_score: 0.9733 - precision: 0.9871 - recall: 0.9865 - lr: 5.0000e-04
# Epoch 108/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0174 - iou_score: 0.9742 - precision: 0.9879 - recall: 0.9867
# Epoch 108: loss improved from 0.01808 to 0.01743, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 0.0174 - iou_score: 0.9742 - precision: 0.9879 - recall: 0.9867 - lr: 5.0000e-04
# Epoch 109/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0167 - iou_score: 0.9750 - precision: 0.9882 - recall: 0.9873
# Epoch 109: loss improved from 0.01743 to 0.01674, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0167 - iou_score: 0.9750 - precision: 0.9882 - recall: 0.9873 - lr: 5.0000e-04
# Epoch 110/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0164 - iou_score: 0.9757 - precision: 0.9882 - recall: 0.9879
# Epoch 110: loss improved from 0.01674 to 0.01636, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 0.0164 - iou_score: 0.9757 - precision: 0.9882 - recall: 0.9879 - lr: 5.0000e-04
# Epoch 111/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0160 - iou_score: 0.9763 - precision: 0.9885 - recall: 0.9880
# Epoch 111: loss improved from 0.01636 to 0.01599, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 0.0160 - iou_score: 0.9763 - precision: 0.9885 - recall: 0.9880 - lr: 5.0000e-04
# Epoch 112/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0164 - iou_score: 0.9758 - precision: 0.9885 - recall: 0.9874
# Epoch 112: loss did not improve from 0.01599
# 113/113 [==============================] - 7s 62ms/step - loss: 0.0164 - iou_score: 0.9758 - precision: 0.9885 - recall: 0.9874 - lr: 5.0000e-04
# Epoch 113/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0167 - iou_score: 0.9753 - precision: 0.9879 - recall: 0.9878
# Epoch 113: loss did not improve from 0.01599
# 113/113 [==============================] - 7s 62ms/step - loss: 0.0167 - iou_score: 0.9753 - precision: 0.9879 - recall: 0.9878 - lr: 5.0000e-04
# Epoch 114/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0164 - iou_score: 0.9753 - precision: 0.9879 - recall: 0.9880
# Epoch 114: loss did not improve from 0.01599
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0164 - iou_score: 0.9753 - precision: 0.9879 - recall: 0.9880 - lr: 5.0000e-04
# Epoch 115/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0161 - iou_score: 0.9757 - precision: 0.9884 - recall: 0.9881
# Epoch 115: loss did not improve from 0.01599
# 113/113 [==============================] - 7s 62ms/step - loss: 0.0161 - iou_score: 0.9757 - precision: 0.9884 - recall: 0.9881 - lr: 5.0000e-04
# Epoch 116/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0158 - iou_score: 0.9761 - precision: 0.9888 - recall: 0.9881
# Epoch 116: loss improved from 0.01599 to 0.01579, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 0.0158 - iou_score: 0.9761 - precision: 0.9888 - recall: 0.9881 - lr: 5.0000e-04
# Epoch 117/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0159 - iou_score: 0.9760 - precision: 0.9886 - recall: 0.9881
# Epoch 117: loss did not improve from 0.01579
# 113/113 [==============================] - 7s 63ms/step - loss: 0.0159 - iou_score: 0.9760 - precision: 0.9886 - recall: 0.9881 - lr: 5.0000e-04
# Epoch 118/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0165 - iou_score: 0.9754 - precision: 0.9885 - recall: 0.9875
# Epoch 118: loss did not improve from 0.01579
# 113/113 [==============================] - 7s 62ms/step - loss: 0.0165 - iou_score: 0.9754 - precision: 0.9885 - recall: 0.9875 - lr: 5.0000e-04
# Epoch 119/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0166 - iou_score: 0.9752 - precision: 0.9884 - recall: 0.9871
# Epoch 119: loss did not improve from 0.01579
# 113/113 [==============================] - 7s 65ms/step - loss: 0.0166 - iou_score: 0.9752 - precision: 0.9884 - recall: 0.9871 - lr: 5.0000e-04
# Epoch 120/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0159 - iou_score: 0.9764 - precision: 0.9887 - recall: 0.9880
# Epoch 120: loss did not improve from 0.01579
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0159 - iou_score: 0.9764 - precision: 0.9887 - recall: 0.9880 - lr: 5.0000e-04
# Epoch 121/250
# 113/113 [==============================] - ETA: 0s - loss: 0.0154 - iou_score: 0.9769 - precision: 0.9889 - recall: 0.9885
# ...
# 113/113 [==============================] - 10s 86ms/step - loss: 1.5433e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 0.9999 - lr: 3.1250e-05
# Epoch 217/250
# 113/113 [==============================] - ETA: 0s - loss: 1.4369e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 217: loss improved from 0.00015 to 0.00014, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 1.4369e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 218/250
# 113/113 [==============================] - ETA: 0s - loss: 1.3459e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 218: loss improved from 0.00014 to 0.00013, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 1.3459e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 219/250
# 113/113 [==============================] - ETA: 0s - loss: 1.2650e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 219: loss improved from 0.00013 to 0.00013, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 1.2650e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 220/250
# 113/113 [==============================] - ETA: 0s - loss: 1.1916e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 220: loss improved from 0.00013 to 0.00012, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 84ms/step - loss: 1.1916e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 221/250
# 113/113 [==============================] - ETA: 0s - loss: 1.1239e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 221: loss improved from 0.00012 to 0.00011, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 1.1239e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 222/250
# 112/113 [============================>.] - ETA: 0s - loss: 1.0404e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000
# Epoch 222: loss improved from 0.00011 to 0.00011, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 1.0609e-04 - iou_score: 0.9999 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 223/250
# 113/113 [==============================] - ETA: 0s - loss: 1.0009e-04 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 223: loss improved from 0.00011 to 0.00010, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 88ms/step - loss: 1.0009e-04 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 224/250
# 112/113 [============================>.] - ETA: 0s - loss: 9.2646e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 224: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 224: loss improved from 0.00010 to 0.00009, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 84ms/step - loss: 9.4570e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.1250e-05
# Epoch 225/250
# 113/113 [==============================] - ETA: 0s - loss: 8.8965e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 225: loss improved from 0.00009 to 0.00009, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 86ms/step - loss: 8.8965e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 226/250
# 113/113 [==============================] - ETA: 0s - loss: 8.6036e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 226: loss improved from 0.00009 to 0.00009, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 84ms/step - loss: 8.6036e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 227/250
# 113/113 [==============================] - ETA: 0s - loss: 8.3152e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 227: loss improved from 0.00009 to 0.00008, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 85ms/step - loss: 8.3152e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 228/250
# 113/113 [==============================] - ETA: 0s - loss: 8.0444e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 228: loss improved from 0.00008 to 0.00008, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 95ms/step - loss: 8.0444e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 229/250
# 113/113 [==============================] - ETA: 0s - loss: 7.7765e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 229: loss improved from 0.00008 to 0.00008, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 90ms/step - loss: 7.7765e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 230/250
# 113/113 [==============================] - ETA: 0s - loss: 7.5076e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 230: loss improved from 0.00008 to 0.00008, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 100ms/step - loss: 7.5076e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 231/250
# 113/113 [==============================] - ETA: 0s - loss: 7.2484e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 231: loss improved from 0.00008 to 0.00007, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 94ms/step - loss: 7.2484e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 232/250
# 113/113 [==============================] - ETA: 0s - loss: 6.9914e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 232: loss improved from 0.00007 to 0.00007, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 95ms/step - loss: 6.9914e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 233/250
# 113/113 [==============================] - ETA: 0s - loss: 6.7366e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 233: loss improved from 0.00007 to 0.00007, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 6.7366e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 234/250
# 113/113 [==============================] - ETA: 0s - loss: 6.4852e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 234: loss improved from 0.00007 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 96ms/step - loss: 6.4852e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 235/250
# 113/113 [==============================] - ETA: 0s - loss: 6.2328e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 235: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 235: loss improved from 0.00006 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 93ms/step - loss: 6.2328e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 1.5625e-05
# Epoch 236/250
# 113/113 [==============================] - ETA: 0s - loss: 5.9790e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 236: loss improved from 0.00006 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 5.9790e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 237/250
# 113/113 [==============================] - ETA: 0s - loss: 5.8365e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 237: loss improved from 0.00006 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 92ms/step - loss: 5.8365e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 238/250
# 113/113 [==============================] - ETA: 0s - loss: 5.7067e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 238: loss improved from 0.00006 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 87ms/step - loss: 5.7067e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 239/250
# 113/113 [==============================] - ETA: 0s - loss: 5.5791e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 239: loss improved from 0.00006 to 0.00006, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 89ms/step - loss: 5.5791e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 240/250
# 113/113 [==============================] - ETA: 0s - loss: 5.4498e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 240: loss improved from 0.00006 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 5.4498e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 241/250
# 113/113 [==============================] - ETA: 0s - loss: 5.3231e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 241: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 99ms/step - loss: 5.3231e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 242/250
# 113/113 [==============================] - ETA: 0s - loss: 5.1922e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 242: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 10s 91ms/step - loss: 5.1922e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 243/250
# 113/113 [==============================] - ETA: 0s - loss: 5.0648e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 243: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 101ms/step - loss: 5.0648e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 244/250
# 113/113 [==============================] - ETA: 0s - loss: 4.9352e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 244: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 99ms/step - loss: 4.9352e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 245/250
# 113/113 [==============================] - ETA: 0s - loss: 4.8082e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 245: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 245: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 99ms/step - loss: 4.8082e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 7.8125e-06
# Epoch 246/250
# 113/113 [==============================] - ETA: 0s - loss: 4.6761e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 246: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 99ms/step - loss: 4.6761e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.9063e-06
# Epoch 247/250
# 113/113 [==============================] - ETA: 0s - loss: 4.5996e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 247: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 95ms/step - loss: 4.5996e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.9063e-06
# Epoch 248/250
# 113/113 [==============================] - ETA: 0s - loss: 4.5341e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 248: loss improved from 0.00005 to 0.00005, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 94ms/step - loss: 4.5341e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.9063e-06
# Epoch 249/250
# 113/113 [==============================] - ETA: 0s - loss: 4.4671e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 249: loss improved from 0.00005 to 0.00004, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 93ms/step - loss: 4.4671e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.9063e-06
# Epoch 250/250
# 113/113 [==============================] - ETA: 0s - loss: 4.3994e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 250: loss improved from 0.00004 to 0.00004, saving model to c:\Users\tiago\miniconda3\envs\tf2_10\data\modelos\unet_red_256x256_F_NUM_128_DT_09_May_14h32min.h5
# 113/113 [==============================] - 11s 96ms/step - loss: 4.3994e-05 - iou_score: 1.0000 - precision: 1.0000 - recall: 1.0000 - lr: 3.9063e-06

# %% [markdown]
# ### Test Set Results

# %%
print("\nSummary of Test Set Results")
print(f' IoU = {np.mean(score_test[1])*100:.2f} %') 
print(f' Precision = {np.mean(score_test[2])*100:.2f} %')
print(f' Recall = {np.mean(score_test[3])*100:.2f} %')
# Out:
# Summary of Test Set Results
#  IoU = 92.74 %
#  Precision = 97.15 %
#  Recall = 95.34 %
